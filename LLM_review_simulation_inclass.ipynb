# %% [markdown]
# # ICLR LLM Review Simulation
#
# This notebook simulates an ICLR-style paper review pipeline using Microsoft AutoGen and OpenAI `gpt-4o-mini`. Provide a PDF manuscript, configure reviewer personas and editor behavior, then run multi-round simulations to observe decision distributions (oral, spotlight, poster, reject).

# %% [markdown]
# ## Setup

# %% [markdown]
# > **Setup**
# > 1. Install dependencies with the next cell.
# > 2. Set the `OPENAI_API_KEY` environment variable (or populate a local `.env`).  The notebook will refuse to run simulations without it.
# > 3. Provide an absolute path to the target PDF when prompted later.

# %%
# Uncomment the code below to install required packages.
# You would need to restart your kernel after running this cell.
# %pip install "autogen-agentchat==0.2.40" pandas matplotlib python-dotenv requests tqdm
# Out:
# Requirement already satisfied: autogen-agentchat==0.2.40 in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (0.2.40)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (2.3.3)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (3.10.7)
# Requirement already satisfied: python-dotenv in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (1.2.1)
# Requirement already satisfied: requests in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (2.32.5)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (4.67.1)
# Requirement already satisfied: diskcache in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (from autogen-agentchat==0.2.40) (5.6.3)
# Requirement already satisfied: docker in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (from autogen-agentchat==0.2.40) (7.1.0)
# Requirement already satisfied: flaml in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (from autogen-agentchat==0.2.40) (2.3.6)
# Requirement already satisfied: numpy<2,>=1.17.0 in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (from autogen-agentchat==0.2.40) (1.26.4)
# Requirement already satisfied: openai>=1.3 in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (from autogen-agentchat==0.2.40) (2.3.0)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (from autogen-agentchat==0.2.40) (25.0)
# Requirement already satisfied: pydantic!=2.6.0,<3,>=1.10 in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (from autogen-agentchat==0.2.40) (2.12.2)
# Requirement already satisfied: termcolor in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (from autogen-agentchat==0.2.40) (3.2.0)
# Requirement already satisfied: tiktoken in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (from autogen-agentchat==0.2.40) (0.12.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (from pydantic!=2.6.0,<3,>=1.10->autogen-agentchat==0.2.40) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (from pydantic!=2.6.0,<3,>=1.10->autogen-agentchat==0.2.40) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (from pydantic!=2.6.0,<3,>=1.10->autogen-agentchat==0.2.40) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (from pydantic!=2.6.0,<3,>=1.10->autogen-agentchat==0.2.40) (0.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (from requests) (2025.10.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (from openai>=1.3->autogen-agentchat==0.2.40) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (from openai>=1.3->autogen-agentchat==0.2.40) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (from openai>=1.3->autogen-agentchat==0.2.40) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (from openai>=1.3->autogen-agentchat==0.2.40) (0.11.0)
# Requirement already satisfied: sniffio in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (from openai>=1.3->autogen-agentchat==0.2.40) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai>=1.3->autogen-agentchat==0.2.40) (1.3.0)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai>=1.3->autogen-agentchat==0.2.40) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.3->autogen-agentchat==0.2.40) (0.16.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: regex>=2022.1.18 in /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages (from tiktoken->autogen-agentchat==0.2.40) (2025.11.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
import os
import random
import re
import time
import zlib
from dataclasses import dataclass
from datetime import datetime
from itertools import combinations
from pathlib import Path
from typing import Any, Dict, Iterable, List, Optional, Sequence, Tuple, Union
import xml.etree.ElementTree as ET

from IPython.display import display
import ipywidgets as W
from openai import OpenAI
from tqdm import tqdm

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
from autogen import AssistantAgent, UserProxyAgent
from dotenv import load_dotenv

load_dotenv()
plt.style.use("ggplot")

DEFAULT_LLM_CONFIG = {
    "model": "gpt-4o-mini",
    "timeout": 120,
}

if "gpt-5" in DEFAULT_LLM_CONFIG["model"]:
    DEFAULT_LLM_CONFIG["max_completion_tokens"] = 10_000
else:
    DEFAULT_LLM_CONFIG["max_tokens"] = 10_000

DECISION_LABELS = ["oral", "spotlight", "poster", "reject"]
REMOTE_SCHEMES = {"http", "https"}
# Out:
# /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages/flaml/__init__.py:20: UserWarning: flaml.automl is not available. Please install flaml[automl] to enable AutoML functionalities.
#   warnings.warn("flaml.automl is not available. Please install flaml[automl] to enable AutoML functionalities.")

# %%
import autogen
autogen.__version__
# Out:
# '0.2.40'

# %% [markdown]
# ## LLM Agent Helper

# %%
def build_llm_config(overrides: Optional[Dict[str, Any]] = None) -> Dict[str, Any]:
    config: Dict[str, Any] = {**DEFAULT_LLM_CONFIG}
    if overrides:
        config.update(overrides)
    config_list = [
        {
            "model": config["model"],
            "api_key": require_api_key(),
        }
    ]
    config["config_list"] = config_list
    return config

# %% [markdown]
# ## Review Summarization Helper Agent
#
# Here we define a LLM-based helper function `aspects_of_comments` that takes a review comment and has the LLM score how much the comment talks about eight dimensions: the six epistemic aspects (accuracy, clarity, consistency, novelty, replicability, thoroughness) plus overall positive and negative sentiment toward the paper. Optionally, you can call it for multiple rounds on the same comment and average the results, so the scores are “smoothed out” instead of depending on a single model response.

# %%
client_summarizer = OpenAI()

def _aspects_of_comments(comment: str, model: str = DEFAULT_LLM_CONFIG["model"]) -> dict:
    """
    Analyze a review comment and score how much it invokes each epistemic
    aspect/value of the paper (following Smith et al., 2025):

    - accuracy   : truth / correctness / soundness of claims & methods
    - clarity    : writing, structure, and intelligibility (a proxy for simplicity)
    - consistency: internal coherence and fair comparison to prior work
    - novelty    : originality + impact/scope of contribution
    - replicability: reproducibility, data/code availability, and procedural detail
    - thoroughness: completeness of evidence, analyses, controls, and literature

    Returns integer scores from 1 (not mentioned) to 5 (major focus).
    """

    system_prompt = """
You are an expert at analyzing academic paper reviews and identifying the
epistemic values that reviewers invoke in their comments.

Your task is to evaluate how much a given review comment addresses each of the
eight dimensions listed below: the six epistemic aspects plus overall positive
and negative sentiment. You are coding the *content of the comment*, not judging
the paper itself.

Treat praise and criticism symmetrically: a strong critique of clarity and a
strong compliment on clarity are both "about clarity." You are measuring how
central each aspect is in the comment, not whether it is positive or negative.

Use these definitions (adapted from work on epistemic values in scientific
theory choice and peer review):

1. Accuracy
   - What it is: Truth, correctness, and soundness of the paper’s claims,
     methods, analyses, and conclusions.
   - Look for: Comments about validity of methods or identification, bias,
     confounding, missing controls, flawed experimental design, incorrect
     statistics, overclaiming, weak or strong linkage between evidence and
     conclusions, robustness of inferences.

2. Clarity
   - What it is: How clearly the paper communicates its ideas in writing and
     presentation (a practical proxy for simplicity).
   - Look for: Readability, organization, structure of sections, figure and
     table clarity, confusing notation, heavy or undefined jargon, ambiguous
     wording, whether the main contribution is easy or hard to understand.
   - Includes: Remarks like "well written," "hard to follow," "unclear,"
     "the exposition needs work," or detailed suggestions on organization.

3. Consistency
   - What it is: Internal coherence and alignment within the paper, and fairness
     and adequacy of comparison to prior work.
   - Look for: Logical flow from theory to methods to results to conclusions;
     contradictions between sections; inconsistent definitions or measures;
     mismatch between stated goals and what is actually done; missing or unfair
     comparisons to baselines or previous studies; improper use of “standard”
     paradigms or benchmarks.

4. Novelty
   - What it is: Originality of the contribution plus its impact/scope relative
     to existing work (combining “fruitfulness” and “scope”).
   - Look for: Comments on whether the work is new, incremental, derivative,
     or groundbreaking; whether it opens new questions, methods, or datasets;
     significance/importance of the problem; fit with the venue; likelihood
     that others will build on the ideas.
   - Includes: Phrases like "incremental," "original," "innovative," "adds
     little beyond X," "important contribution," "major advance."

5. Replicability
   - What it is: How easy it would be for others to reproduce the study or
     re-run the analysis given the information and resources provided.
   - Look for: Data and code availability; sufficiency of methodological detail
     (preprocessing, model specification, parameter settings, instruments,
     protocols); randomization, sample size justification; whether procedures
     are described clearly enough to reproduce results.
   - Includes: Critiques like "not enough implementation detail," "no code/data
     provided," "methods section too thin," as well as explicit praise for
     detailed, reproducible setups.

6. Thoroughness
   - What it is: Completeness and sufficiency of the empirical and conceptual
     work supporting the paper’s claims.
   - Look for: Scope and coverage of experiments or analyses; missing robustness
     checks or ablations; lack of relevant baselines or controls; narrow data
     that don’t match the ambition of the claims; superficial or incomplete
     engagement with related work; calls for “more experiments,” “more
     analysis,” or “stronger evidence.”
   - Includes: Comments that additional tests, datasets, conditions, or
     literature are needed to fully support the claims.

7. Positive Sentiment
   - What it is: Overall enthusiasm, praise, or supportive tone toward the
     paper’s quality, promise, or readiness for acceptance.
   - Look for: Statements that highlight excitement, strengths outweighing
     weaknesses, strong endorsements, or confidence that the paper should be
     accepted.
   - Includes: Phrases like “I strongly recommend acceptance,” “compelling and
     impactful,” “impressive results,” or repeated emphasis on strengths.

8. Negative Sentiment
   - What it is: Overall skepticism, criticism, or cautionary tone suggesting
     the paper falls short of acceptance standards.
   - Look for: Statements focusing on fatal flaws, inability to recommend
     acceptance, substantial reservations, or emphasis on weaknesses.
   - Includes: Phrases like “I recommend rejection,” “serious flaws,” “not ready
     for publication,” or repeated emphasis on shortcomings.

SCORING RULES (APPLY TO EACH ASPECT INDEPENDENTLY)
- 1: Not mentioned at all (no clear signal for this aspect).
- 2: Briefly touched upon (a passing remark or short phrase).
- 3: Moderately discussed (one or two sentences with some detail).
- 4: Substantially addressed (a major part of the comment, with explanation).
- 5: Major focus of the comment (dominant theme; most of the text concerns it).
- For positive/negative sentiment, use the same 1-5 scale to reflect how strongly the overall tone leans supportive or critical; mixed comments can score moderately on both.

Important:
- Multiple aspects can have high scores if the comment weaves together several
  values (e.g., novelty and accuracy).
- Do NOT let your own view of the paper influence scores; rely only on the
  reviewer's text.
- Treat positive and negative statements equally as evidence that the aspect
  is being addressed.

You MUST respond with ONLY a valid JSON object in this exact format:
{"accuracy": <score>, "clarity": <score>, "consistency": <score>, "novelty": <score>, "replicability": <score>, "thoroughness": <score>, "positive": <score>, "negative": <score>}
"""

    user_prompt = f"""Please analyze the following review comment and score each aspect from 1-5,
based solely on how much the *comment* addresses that aspect. Also rate overall sentiment with two additional dimensions: positive (1-5) and negative (1-5).

=== REVIEW COMMENT ===
{comment}

Respond with only the JSON object containing integer scores for each aspect, including positive and negative sentiment.
"""

    response = client_summarizer.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt},
        ],
        response_format={"type": "json_object"},
    )

    result = json.loads(response.choices[0].message.content)
    return result

def aspects_of_comments(comment: str, model: str = DEFAULT_LLM_CONFIG["model"], num_trials: int = 1, normalize_scores: bool = False) -> dict:
    """
    Call _aspects_of_comments multiple times and return average scores.

    Args:
        comment: The review comment to analyze
        model: The model to use for analysis
        num_trials: Number of times to run the analysis

    Returns:
        dict with average scores for each aspect
    """
    all_results = []
    for _ in range(num_trials):
        result = _aspects_of_comments(comment, model)
        all_results.append(result)

    # Calculate average scores for each aspect
    avg_scores = {}
    aspects = ["accuracy", "clarity", "consistency", "novelty", "replicability", "thoroughness", "positive", "negative"]
    for aspect in aspects:
        avg_scores[aspect] = sum(r[aspect] for r in all_results) / num_trials

    if normalize_scores:
        total = sum(avg_scores.values())
        if total > 0:
            avg_scores = {k: v / total for k, v in avg_scores.items()}
    return avg_scores



def flatten_review_text(record: Union[Dict[str, Any], str]) -> str:
    if isinstance(record, str):
        return record
    block = (record or {}).get("review", {})
    parts: List[str] = []
    for key in ("summary", "strengths", "weaknesses", "questions"):
        value = block.get(key, [])
        if isinstance(value, str):
            parts.append(value)
        elif isinstance(value, list):
            parts.extend([str(item) for item in value if item])
    text = "\n".join(part for part in parts if part).strip()
    return text or ""


def score_review_records(
    records: List[Union[Dict[str, Any], str]],
    source_label: str,
    num_trials: int = 1,
    model: str = DEFAULT_LLM_CONFIG["model"],
) -> List[Dict[str, Any]]:
    scored: List[Dict[str, Any]] = []
    if not records:
        return scored
    for idx, record in enumerate(records, start=1):
        if isinstance(record, str):
            persona = {}
        else:
            persona = record.get("persona", {})
        review_text = flatten_review_text(record)
        if not review_text:
            continue
        scores = aspects_of_comments(review_text, model=model, num_trials=num_trials)
        scored.append(
            {
                "source": source_label,
                "name": persona.get("name", f"{source_label}_{idx}") if persona else f"{source_label}_{idx}",
                "domain": persona.get("expertise", PAPER_DOMAIN) if persona else PAPER_DOMAIN,
                "seniority": persona.get("seniority", "unknown") if persona else "unknown",
                **scores,
            }
        )
    return scored


def compute_aspect_scores(num_trials: int = 1) -> pd.DataFrame:
    rows: List[Dict[str, Any]] = []
    rows.extend(score_review_records(HUMAN_REVIEWS, "human", num_trials=num_trials))
    return pd.DataFrame(rows)

# %% [markdown]
# # TODO #1: put your own OpenAI API key here

# %%
os.environ["OPENAI_API_KEY"] = "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"

# %%
def require_api_key() -> str:
    api_key = os.environ.get("OPENAI_API_KEY")
    if not api_key:
        raise RuntimeError("OPENAI_API_KEY not set. Export it or use a .env file.")
    return api_key

# %% [markdown]
# # TODO # 2: Pick the paper that you would like to simulate review for
#
# choose one paper to load, you can change the paper_parsed to load different papers.

# %%
# GitHub index of available papers (paper_id, file_name)
# choose one paper to load, you can change the paper_parsed to load different papers.

papers_parsed = [
    # ("d5HUnyByAI", "BIO-5177_CLIBD_Bridging_Vision_and"),
    ("Q2bJ2qgcP1", "CAUSALITY-11132_Do_Contemporary_Causal_I"),
    # ("X9OfMNNepI", "CHEM-4321_MOOSE_Chem_Large_Language"),
    # ("hjROBHstZ3", "HEALTH-11612_Causal_Representation_Le"),
    # ("xXTkbTBmqq", "LLMs-211_OLMoE_Open_Mixture_of_Expe"),
    # ("BpfsxFqhGa", "NEURO-3520_Animate_Your_Thoughts_Rec"),
    # ("VsxbWTDHjh", "PHYSICS-3880_Fengbo_a_Clifford_Neural_"),
    # ("d8hYXbxX71", "POLICY-11925_Policy_Design_in_Long_ru"),
    # ("dTPz4rEDok", "RL-10175_Offline_Hierarchical_Rei"),
    # ("awvJBtB2op", "ROBOTICS-11292_Generating_Freeform_Endo"),
]

LOAD_FROM_GITHUB = True  # if you are running on colab, set this to True so that the notebook fetches the paper from Github directly.
GITHUB_BASE_URL = "https://raw.githubusercontent.com/TianyuDu/OB639-LLM-ABM-Simulation/refs/heads/main/pdfs_parsed/"
LOCAL_PATH = "./pdf_parsed"
PAPER_ID, PAPER_FILE_NAME = random.choice(papers_parsed)
PAPER_PATH = f"{PAPER_FILE_NAME}/{PAPER_FILE_NAME}.tei.xml"

if LOAD_FROM_GITHUB:
    PAPER_PATH = f"{GITHUB_BASE_URL}{PAPER_PATH}"
else:
    PAPER_PATH = f"{LOCAL_PATH}/{PAPER_PATH}"

print(f"Loading paper from: {PAPER_PATH}")
print(f"Paper File Name {PAPER_FILE_NAME}")
# Out:
# Loading paper from: https://raw.githubusercontent.com/TianyuDu/OB639-LLM-ABM-Simulation/refs/heads/main/pdfs_parsed/CAUSALITY-11132_Do_Contemporary_Causal_I/CAUSALITY-11132_Do_Contemporary_Causal_I.tei.xml
# Paper File Name CAUSALITY-11132_Do_Contemporary_Causal_I

# %% [markdown]
# # TODO #3: Write Reviewer Persona

# %%
# DEFAULT_PAPER_DOMAIN = "Machine Learning"

# PAPER_FILE_NAME_TO_DOMAIN = {
#     "BIO": "Biology",
#     "CAUSALITY": "Causality",
#     "CHEM": "Chemistry",
#     "CV": "Computer Vision",
#     "DL": "Deep Learning",
#     "GNN": "Graph Neural Networks",
#     "HEALTH": "Health",
#     "LLMs": "Large Language Models",
#     "ML": "Machine Learning",
#     "NEURO": "Neuroscience",
#     "NLP": "Natural Language Processing",
#     "OPT": "Optimization",
#     "PHYSICS": "Physics",
#     "POLICY": "Policy",
#     "ACCEL": "Accelerated Computing",
#     "RL": "Reinforcement Learning",
#     "ROBOTICS": "Robotics",
#     "SOFT": "Software Engineering",
#     "SP": "Signal Processing",
#     "SYST": "Systems",
#     "ACOU": "Acoustics",
#     "AGI": "Artificial General Intelligence",
#     "ALIGN": "AI Alignment",
#     "AUDIO": "Audio Processing",
#     "AUTO": "Autonomous Systems",
#     "BAYES": "Bayesian Methods",
#     "BENCH": "Benchmarking",
#     "CLIP": "Vision-Language Models",
#     "CONT": "Continual Learning",
#     "DATA": "Data Science",
#     "DIFF": "Diffusion Models",
#     "DIST": "Distributed Systems",
#     "ECON": "Economics",
#     "ENERGY": "Energy",
#     "FAIR": "Fairness and Bias",
#     "FED": "Federated Learning",
#     "FM": "Foundation Models",
#     "GEN": "Generative Models",
#     "GEOM": "Geometric Deep Learning",
#     "INTERP": "Interpretability",
#     "KG": "Knowledge Graphs",
#     "META": "Meta-Learning",
#     "MULTI": "Multimodal Learning",
#     "NAS": "Neural Architecture Search",
#     "PINN": "Physics-Informed Neural Networks",
#     "PRIV": "Privacy",
#     "PROB": "Probabilistic Methods",
#     "QUANT": "Quantization",
#     "REC": "Recommender Systems",
#     "REP": "Representation Learning",
#     "SAFE": "AI Safety",
#     "SCALE": "Scalability",
#     "SEC": "Security",
#     "SELF": "Self-Supervised Learning",
#     "SIM": "Simulation",
#     "SPEECH": "Speech Processing",
#     "STAT": "Statistics",
#     "THEO": "Theory",
#     "TIME": "Time Series",
#     "TRANS": "Transformers",
#     "TRUST": "Trustworthy AI",
#     "VID": "Video Understanding",
# }

# # Level of seniority for AI reviewers.
# SENIORITY_OPTIONS_ALLOWED = [
#     "Graduate student",
#     "Junior faculty",
#     "Senior faculty",
#     "random",  # let the system randomly pick one from the list.
# ]

# # Domain of expertise for AI reviewers.
# DOMAIN_OPTIONS = [
#     "same",  # use the same domain as the paper.
#     "random_different",  # let the system randomly pick one from the list of domains AVAILABLE_DOMAINS that is different from the paper's domain.
#     # You can customize the AVAILABLE_DOMAINS variable above to include more domains or remove some domains.
# ]

# %%
# Configure your AI reviewer panel by editing this list.
# Each entry should have:
#   - "domain": expertise area (use PAPER_DOMAIN for same as paper, or pick from AVAILABLE_DOMAINS)
#   - "seniority": one of "Graduate student", "Junior faculty", "Senior faculty", or "random"

# This current setup is the default setup
AI_PANEL_STATE: List[Dict[str, str]] = [
    {"domain": "Machine Learning", "seniority": "Junior faculty"},
    {"domain": "Machine Learning", "seniority": "Junior faculty"},
    {"domain": "Machine Learning", "seniority": "Junior faculty"},
    {"domain": "Machine Learning", "seniority": "Junior faculty"},
    {"domain": "Machine Learning", "seniority": "Junior faculty"},
]

# %% [markdown]
# # Run & Read: Load Data from ICLR & Develop Understanding of the ICLR Peer-review Process

# %% [markdown]
# ## Read & Understand the process
#
# Here, we first read reviews and decisions for 100 ICLR 2025 paper submissions. You can read this section to understand what data ICLR log in its OpenReview system.

# %%
df_ICLR_2025 = pd.read_csv("https://raw.githubusercontent.com/TianyuDu/OB639-LLM-ABM-Simulation/refs/heads/main/data/ICLR2025/classroom_ICLR2025_human_reviews_with_decision_selected_100.csv")
df_ICLR_2025["review"] = "Summary:\n" + df_ICLR_2025["summary"].fillna("None") + "\n\nStrengths:\n" + df_ICLR_2025["strengths"].fillna("None") + "\n\nWeaknesses:\n" + df_ICLR_2025["weaknesses"].fillna("None") + "\n\nQuestions:\n" + df_ICLR_2025["questions"].fillna("None")

# %%
df_ICLR_2025.head(2)
# Out:
#   paper_forum    paper_id                                              title  \
# 0  UHg1xTRzZK  UHg1xTRzZK  Boosting LLM Translation Skills without Genera...
# 1  UHg1xTRzZK  UHg1xTRzZK  Boosting LLM Translation Skills without Genera...
#
#   decision   review_id                                        reviewer_id  \
# 0   Reject  oMGCQ3oLMJ  ICLR.cc/2025/Conference/Submission13856/Review...
# 1   Reject  WLVuZGI9k6  ICLR.cc/2025/Conference/Submission13856/Review...
#
#                                              summary  \
# 0  The paper proposed rationale distillation, wit...
# 1  The paper introduces RaDis (Rationale Distilla...
#
#                                            strengths  \
# 0  The paper successfully did what they proposed,...
# 1  1. The authors propose a straightforward metho...
#
#                                           weaknesses  \
# 0  1. The paper's goal is good —it aims to genera...
# 1  1. The paper only focuses on improving transla...
#
#                                            questions  \
# 0                                                NaN
# 1  The proposed method generates a rationale for ...
#
#                                               review
# 0  Summary:\nThe paper proposed rationale distill...
# 1  Summary:\nThe paper introduces RaDis (Rational...

# %%
df_ICLR_2025["paper_id"].nunique()
# Out:
# 100

# %% [markdown]
# ### Distribution of Decisions

# %%
decision_counts = df_ICLR_2025["decision"].value_counts()
colors = ['#2ecc71', '#3498db', '#f39c12', '#e74c3c']  # green, blue, orange, red
labels_with_counts = [f'{label}\n(n={count})' for label, count in zip(decision_counts.index, decision_counts.values)]

plt.figure(figsize=(8, 8), dpi=300)
plt.pie(decision_counts, labels=labels_with_counts, autopct='%1.1f%%', startangle=90,
        colors=colors, explode=[0.02]*len(decision_counts), shadow=False,
        textprops={'fontsize': 12, 'fontweight': 'bold'})
plt.title("Distribution of Paper Decisions", fontsize=16, fontweight='bold')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### A typcial review looks like the following: it includes a summary, lists of strengths, weaknesses, and questions.

# %%
print(df_ICLR_2025["review"].iloc[0])
# Out:
# Summary:
# The paper proposed rationale distillation, with a purpose on improving LLM-based models translation performance while keeping the general instruction-following abilities. The method first generates the explanation of the translation and use the synthetic data for fine-tuning along with the translation pairs.
#
# Strengths:
# The paper successfully did what they proposed, improving the translation performance with the proposed method can significantly reduce the damage in general instruction-following tasks.
#
# Weaknesses:
# 1. The paper's goal is good —it aims to generalize translation models based on LLMs to other domains such as conversational tasks. However, the attempt to balance both translation quality and generalization does not yield a model that is truly useful, placing the paper in an awkward position. For example, RaDis performs substantially worse than its backbone model on conversations and instruction following, and its translation performance is inferior to that of translation-specific models. While I acknowledge that comparing RaDis with ALMA in terms of translation is not entirely fair due to differences in models and training data, this raises another issue: the model's performance is highly dependent on the backbone model. Consequently, RaDis cannot be effectively applied to low-resource languages like Icelandic, which were excluded from the training data. Achieving effective machine translation in LLMs requires substantial effort in multilingual pretraining and alignment; without this, English-centric LLM translation performance is less interesting. Despite the paper's claims of keeping both translation high performance and retaining generality, the translation quality is not top due to the high dependency of the backbone model, and the performance on other tasks is also worse.
#
# 2. Inference speed: Regarding inference speed, if the model is trained to output both a reference and an explanation, does this mean the generated output always includes both, requiring the user to extract the translation from the combined output? If so, this could significantly reduce inference speed. It would be beneficial to see a comparison of inference speeds and an analysis of how many additional tokens the model generates compared to translation-specific LLMs.
#
# 3. Missing baselines: A fundamental baseline would involve training on a combined dataset of translation parallel data and instruction-following data. Using synthesized data may be unnecessary given the abundance of existing data that can be combined with parallel data. However, I did not find results corresponding to this baseline in the paper. Including such comparisons would strengthen the evaluation and provide a clearer understanding of the model's performance relative to more straightforward approaches.
#
# Questions:
# None

# %% [markdown]
# ### Distribution of number of reviews: each paper receives around 4 reviews, in our simplified simulation, the editor will make a decision based on these four reviews.
#
# Note: in the real ICLR review process, each paper receives around 4 reviews, and there is a "rebuttal" round after the first round of reviews (i.e., the authors write a response to the reviews, and the reviewers write a response to the rebuttal). In our simulation, we simplify this process by directly using the initial reviews to make a decision.

# %%
# Count number of reviews per paper
reviews_per_paper = df_ICLR_2025.groupby("paper_id").size()

# Calculate statistics
mean_reviews = reviews_per_paper.mean()
median_reviews = reviews_per_paper.median()

# Plot histogram
plt.figure(figsize=(10, 6), dpi=300)
plt.hist(reviews_per_paper, bins=range(1, reviews_per_paper.max() + 2),
         edgecolor='black', alpha=0.7, color='#3498db', align='left')
plt.axvline(mean_reviews, color='#e74c3c', linestyle='--', linewidth=2, label=f'Mean: {mean_reviews:.2f}')
plt.axvline(median_reviews, color='#2ecc71', linestyle='--', linewidth=2, label=f'Median: {median_reviews:.2f}')
plt.xlabel("Number of Reviews per Paper", fontsize=12, fontweight='bold')
plt.ylabel("Number of Papers", fontsize=12, fontweight='bold')
plt.title("Distribution of Number of Reviews per Paper", fontsize=14, fontweight='bold')
plt.xticks(range(1, reviews_per_paper.max() + 1))
plt.legend(fontsize=11)
plt.tight_layout()
plt.show()

print(f"Mean number of reviews per paper: {mean_reviews:.2f}")
print(f"Median number of reviews per paper: {median_reviews:.2f}")
print(f"Total papers: {len(reviews_per_paper)}")
print(f"Total reviews: {len(df_ICLR_2025)}")
# Out:
# Mean number of reviews per paper: 4.12
# Median number of reviews per paper: 4.00
# Total papers: 100
# Total reviews: 412

# %% [markdown]
# ### Decisions Available

# %%
DECISION_LABELS = pd.unique(df_ICLR_2025["decision"]).tolist()
print(f"Decision labels: {DECISION_LABELS}")
# Out:
# Decision labels: ['Reject', 'Accept (Poster)', 'Accept (Spotlight)', 'Accept (Oral)']

# %% [markdown]
# ### Note: we do not know the identity of the reviewers (but we do for ICLR 2026... unethical to use that data!)

# %% [markdown]
# ## Run & Read: For In-class Simulation Exploration, we will focus on the paper you have selected earlier
#
# We now load one paper with the full text, which was parsed from the PDF file. We will be focusing on how comments from different reviews will shape the (LLM) editor's decision.

# %% [markdown]
# ### Just run: Load Pre-parsed Paper Text & Get paper domain

# %%
DEFAULT_PAPER_DOMAIN = "Machine Learning"

PAPER_FILE_NAME_TO_DOMAIN = {
    "BIO": "Biology",
    "CAUSALITY": "Causality",
    "CHEM": "Chemistry",
    "CV": "Computer Vision",
    "DL": "Deep Learning",
    "GNN": "Graph Neural Networks",
    "HEALTH": "Health",
    "LLMs": "Large Language Models",
    "ML": "Machine Learning",
    "NEURO": "Neuroscience",
    "NLP": "Natural Language Processing",
    "OPT": "Optimization",
    "PHYSICS": "Physics",
    "POLICY": "Policy",
    "ACCEL": "Accelerated Computing",
    "RL": "Reinforcement Learning",
    "ROBOTICS": "Robotics",
    "SOFT": "Software Engineering",
    "SP": "Signal Processing",
    "SYST": "Systems",
    "ACOU": "Acoustics",
    "AGI": "Artificial General Intelligence",
    "ALIGN": "AI Alignment",
    "AUDIO": "Audio Processing",
    "AUTO": "Autonomous Systems",
    "BAYES": "Bayesian Methods",
    "BENCH": "Benchmarking",
    "CLIP": "Vision-Language Models",
    "CONT": "Continual Learning",
    "DATA": "Data Science",
    "DIFF": "Diffusion Models",
    "DIST": "Distributed Systems",
    "ECON": "Economics",
    "ENERGY": "Energy",
    "FAIR": "Fairness and Bias",
    "FED": "Federated Learning",
    "FM": "Foundation Models",
    "GEN": "Generative Models",
    "GEOM": "Geometric Deep Learning",
    "INTERP": "Interpretability",
    "KG": "Knowledge Graphs",
    "META": "Meta-Learning",
    "MULTI": "Multimodal Learning",
    "NAS": "Neural Architecture Search",
    "PINN": "Physics-Informed Neural Networks",
    "PRIV": "Privacy",
    "PROB": "Probabilistic Methods",
    "QUANT": "Quantization",
    "REC": "Recommender Systems",
    "REP": "Representation Learning",
    "SAFE": "AI Safety",
    "SCALE": "Scalability",
    "SEC": "Security",
    "SELF": "Self-Supervised Learning",
    "SIM": "Simulation",
    "SPEECH": "Speech Processing",
    "STAT": "Statistics",
    "THEO": "Theory",
    "TIME": "Time Series",
    "TRANS": "Transformers",
    "TRUST": "Trustworthy AI",
    "VID": "Video Understanding",
}

PAPER_DOMAIN = PAPER_FILE_NAME_TO_DOMAIN.get(PAPER_FILE_NAME.split("-")[0], DEFAULT_PAPER_DOMAIN)
print("The domain of this paper is:", PAPER_DOMAIN)
AVAILABLE_DOMAINS = list(PAPER_FILE_NAME_TO_DOMAIN.values())
print(HUMAN_REVIEWS[0])
print(AVAILABLE_DOMAINS)
# Out:
# The domain of this paper is: Causality
# Summary:
# The paper proposes a new statistical parameter to evaluate the performance of a method to estimate CATE. Then the paper shows that this parameter can be consistently estimated. Finally the paper demonstrates that this parameter can be used to select estimation methods for CATE.
#
# Strengths:
# - The statistical parameter proposed in the paper is simple to implement and makes intuitive sense.
# - Theoretical guarantees are provided.
# - The paper compares many estimation methods for CATE in the empirical application.
#
# Weaknesses:
# - The paper largely overclaims the number of datasets. Essentially, there are only 12 unique datasets and the paper uses a bunch of sampling methods to create many more variants of the original 12 datasets.
# - The findings in the first paragraph of the abstract have been known for a long time, and they are not unexpected, as claimed in the paper. The estimation of CATE is known to be very noisy, and that's why the causal inference literature has primarily focused on the estimation of ATE (but not CATE) for decades.
# - The clarity and rigor of the paper need to be improved. For example, the term "CATE model" is a bit awkward and is rarely used in the literature. CATE is an estimand commonly defined based on potential outcomes. When "CATE model" is used, it is unclear whether this term refers to an outcome model to define CATE or an estimation method for CATE.
#
# Questions:
# Please address the weaknesses above.
# ['Biology', 'Causality', 'Chemistry', 'Computer Vision', 'Deep Learning', 'Graph Neural Networks', 'Health', 'Large Language Models', 'Machine Learning', 'Neuroscience', 'Natural Language Processing', 'Optimization', 'Physics', 'Policy', 'Accelerated Computing', 'Reinforcement Learning', 'Robotics', 'Software Engineering', 'Signal Processing', 'Systems', 'Acoustics', 'Artificial General Intelligence', 'AI Alignment', 'Audio Processing', 'Autonomous Systems', 'Bayesian Methods', 'Benchmarking', 'Vision-Language Models', 'Continual Learning', 'Data Science', 'Diffusion Models', 'Distributed Systems', 'Economics', 'Energy', 'Fairness and Bias', 'Federated Learning', 'Foundation Models', 'Generative Models', 'Geometric Deep Learning', 'Interpretability', 'Knowledge Graphs', 'Meta-Learning', 'Multimodal Learning', 'Neural Architecture Search', 'Physics-Informed Neural Networks', 'Privacy', 'Probabilistic Methods', 'Quantization', 'Recommender Systems', 'Representation Learning', 'AI Safety', 'Scalability', 'Security', 'Self-Supervised Learning', 'Simulation', 'Speech Processing', 'Statistics', 'Theory', 'Time Series', 'Transformers', 'Trustworthy AI', 'Video Understanding']

# %%
if LOAD_FROM_GITHUB:
    response = requests.get(PAPER_PATH)
    response.raise_for_status()
    TEI_XML_CONTENT = response.text
else:
    with open(PAPER_PATH, "r", encoding="utf-8") as f:
        TEI_XML_CONTENT = f.read()

print(f"Loaded paper content: {len(TEI_XML_CONTENT)} characters")
# Out:
# Loaded paper content: 133017 characters

# %%
def extract_text_from_tei(tei_content: str) -> str:
    """Extract paper text from TEI XML content."""
    if not tei_content:
        return None

    root = ET.fromstring(tei_content)

    # Define namespaces
    ns = {'tei': 'http://www.tei-c.org/ns/1.0'}

    text_parts = []

    # Extract title
    title = root.find('.//tei:titleStmt/tei:title[@level="a"][@type="main"]', ns)
    if title is not None and title.text:
        text_parts.append(f"Title: {title.text}\n")

    # Extract abstract
    abstract = root.find('.//tei:abstract', ns)
    if abstract is not None:
        abstract_text = ' '.join(abstract.itertext())
        text_parts.append(f"Abstract: {abstract_text}\n\n")

    # Extract body text
    body = root.find('.//tei:body', ns)
    if body is not None:
        for div in body.findall('.//tei:div', ns):
            # Get section heading
            head = div.find('tei:head', ns)
            if head is not None and head.text:
                text_parts.append(f"\n{head.text}\n")

            # Get all paragraphs
            for p in div.findall('.//tei:p', ns):
                p_text = ' '.join(p.itertext())
                # Clean up extra whitespace
                p_text = ' '.join(p_text.split())
                if p_text:
                    text_parts.append(f"{p_text}\n\n")

    return ''.join(text_parts)

def text_summary(text: str) -> str:
    sentences = re.split(r'[.!?]+', text)
    sentence_count = len([s for s in sentences if s.strip()])
    word_count = len(text.split())
    char_count = len(text)
    estimated_pages = word_count / 500
    return f"{sentence_count:,} sentences, {word_count:,} words, ~{estimated_pages:.1f} pages (double-spaced)"

# %%
PAPER_TEXT = extract_text_from_tei(TEI_XML_CONTENT)

# examine the first 1000 characters of the paper text
print(f"{PAPER_ID=:}\n{PAPER_TEXT[:1000]=:}")

# summarize sentence and word counts
print(f"\nPaper text summary: {text_summary(PAPER_TEXT)}")
# Out:
# PAPER_ID=Q2bJ2qgcP1
# PAPER_TEXT[:1000]=Title: DO CONTEMPORARY CAUSAL INFERENCE MODELS CAPTURE REAL-WORLD HETEROGENEITY? FINDINGS FROM A LARGE-SCALE BENCHMARK
# Abstract:
#  We present unexpected findings from a large-scale benchmark study evaluating Conditional Average Treatment Effect (CATE) estimation algorithms, i.e., CATE models. By running 16 modern CATE models on 12 datasets and 43,200 sampled variants generated through diverse observational sampling strategies, we find that: (a) 62% of CATE estimates have a higher Mean Squared Error (MSE) than a trivial zero-effect predictor, rendering them ineffective; (b) in datasets with at least one useful CATE estimate, 80% still have higher MSE than a constant-effect model; and (c) Orthogonality-based models outperform other models only 30% of the time, despite widespread optimism about their performance. These findings highlight significant challenges in current CATE models and underscore the need for broader evaluation and methodological improvements. Our findings stem from a no
#
# Paper text summary: 525 sentences, 7,675 words, ~15.3 pages (double-spaced)

# %% [markdown]
# ### Run & Read: load human reviews and decisions for your selected paper

# %%
HUMAN_REVIEWS = df_ICLR_2025[df_ICLR_2025["paper_id"] == PAPER_ID]["review"].tolist()
ACTUAL_DECISION = df_ICLR_2025[df_ICLR_2025["paper_id"] == PAPER_ID]["decision"].iloc[0]
print(f"Loaded {len(HUMAN_REVIEWS)} human reviews for paper {PAPER_ID}")
print("\nHuman review summaries:")
for i, review in enumerate(HUMAN_REVIEWS, 1):
    print(f"  Review {i}: {text_summary(review)}")
print(f"\nActual decision (human editor on human reviewers): {ACTUAL_DECISION}")
# Out:
# Loaded 5 human reviews for paper Q2bJ2qgcP1
#
# Human review summaries:
#   Review 1: 15 sentences, 243 words, ~0.5 pages (double-spaced)
#   Review 2: 21 sentences, 338 words, ~0.7 pages (double-spaced)
#   Review 3: 21 sentences, 292 words, ~0.6 pages (double-spaced)
#   Review 4: 23 sentences, 512 words, ~1.0 pages (double-spaced)
#   Review 5: 54 sentences, 563 words, ~1.1 pages (double-spaced)
#
# Actual decision (human editor on human reviewers): Accept (Poster)

# %% [markdown]
# --> Quick Exploration for Human Reviews

# %%
ASPECT_COLUMNS = ["accuracy", "clarity", "consistency", "novelty", "replicability", "thoroughness", "positive", "negative"]

print("Scoring aspects for human reviews …")
ASPECT_SCORES_DF = compute_aspect_scores(num_trials=1)
print(ASPECT_SCORES_DF)

# Draw histogram of aspect scores
plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams.update({
    'font.family': 'sans-serif',
    'font.sans-serif': ['Arial', 'Helvetica', 'DejaVu Sans'],
    'font.size': 11,
    'axes.labelsize': 12,
    'axes.titlesize': 13,
    'xtick.labelsize': 10,
    'ytick.labelsize': 10,
    'figure.dpi': 150,
    'axes.spines.top': False,
    'axes.spines.right': False,
})

# Color palette for consistent styling
COLORS = ['#4C72B0', '#55A868', '#C44E52', '#8172B3', '#CCB974', '#64B5CD', '#1F77B4', '#FF7F0E']

fig, axes = plt.subplots(2, 4, figsize=(16, 9))
axes = axes.flatten()

for idx, aspect in enumerate(ASPECT_COLUMNS):
    ax = axes[idx]
    scores = ASPECT_SCORES_DF[aspect].values

    # Create histogram with improved styling
    n, bins, patches = ax.hist(
        scores,
        bins=np.arange(0.5, 6.5, 1),
        edgecolor='white',
        linewidth=1.2,
        color=COLORS[idx],
        alpha=0.85
    )

    # Add mean line
    mean_val = np.mean(scores)
    ax.axvline(mean_val, color='#333333', linestyle='--', linewidth=1.5, alpha=0.8)
    ax.text(mean_val + 0.1, ax.get_ylim()[1] * 0.9, f'μ={mean_val:.2f}',
            fontsize=9, color='#333333', fontweight='bold')

    ax.set_xlabel('Score', fontweight='medium')
    ax.set_ylabel('Count', fontweight='medium')
    ax.set_title(f'{aspect.title()}', fontweight='bold', pad=10)
    # ax.set_xticks([1, 2, 3, 4, 5])
    # ax.set_xlim(0.5, 5.5)

    # Add subtle grid
    ax.yaxis.grid(True, linestyle='-', alpha=0.3)
    ax.set_axisbelow(True)

plt.suptitle('Distribution of Aspect Scores for Human Reviews', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()
# Out:
# Scoring aspects for human reviews …
#   source     name     domain seniority  accuracy  clarity  consistency  \
# 0  human  human_1  Causality   unknown       3.0      4.0          2.0
# 1  human  human_2  Causality   unknown       3.0      4.0          3.0
# 2  human  human_3  Causality   unknown       3.0      4.0          3.0
# 3  human  human_4  Causality   unknown       3.0      3.0          3.0
# 4  human  human_5  Causality   unknown       4.0      3.0          4.0
#
#    novelty  replicability  thoroughness  positive  negative
# 0      2.0            1.0           3.0       4.0       4.0
# 1      3.0            4.0           4.0       4.0       4.0
# 2      4.0            2.0           3.0       4.0       3.0
# 3      4.0            2.0           4.0       3.0       4.0
# 4      4.0            2.0           3.0       4.0       3.0

# %% [markdown]
# # Just run: Building the LLM Editor Agent
# The editor (or area chair) is a function mapping from a set of reviews (from reviewers) to a final decision regarding the paper. There are four possible outcomes:
#
# 1. Accept (Oral)
# 2. Accept (Spotlight)
# 3. Accept (Poster)
# 4. Reject
#
# (We also include a test run in there to test whether editors make reasonable decisions based on human review)

# %% [markdown]
# ## Just run: Set up LLM Editor Agent

# %%
EDITOR_PROMPT = """You are serving as the Area Chair for an ICLR submission.
You will receive the manuscript text plus a list of reviews (some human-written, some LLM-generated).

Your responsibilities:

1. Analyze all reviews:
   - Identify clear points of consensus across reviewers.
   - Identify and explain disagreements, including which reviewers disagree and why.
   - Flag any reviewer misunderstandings, unsupported claims, or inconsistencies.

2. Conduct an independent Area Chair assessment:
   - Evaluate novelty, technical correctness, significance, empirical rigor, and clarity.
   - Weigh reviewer feedback appropriately, but do not rely on it blindly.
   - Distinguish between major and minor concerns.
   - Note any methodological flaws, missing experiments, ethical issues, or correctness problems that materially affect acceptance.

3. Make and justify the final decision (one of {decisions}):
   - Base the decision on reviewer consensus, resolved disagreements, and your own AC-level judgment.
   - Ensure the justification reflects ICLR standards: correctness > novelty > significance > clarity.
   - The justification must be factual, grounded in the manuscript + reviews, and internally consistent.

4. Return a strict JSON object with no code fences:
{{
  "decision": one of {decisions},
  "confidence": float between 0 and 1,
  "score": integer between 1 and 10,
  "rationale": "A concise paragraph explaining the decision, referencing consensus, disagreements, and your independent assessment.",
  "highlights": [
    "Key factor influencing the decision",
    "Another key factor",
    "Major consensus or disagreement point",
    "Any important caveat or uncertainty"
  ]
}}
""".format(decisions=DECISION_LABELS)

# %%
def make_editor_agent(overrides: Optional[Dict[str, Any]] = None) -> AssistantAgent:
    llm_config = build_llm_config(overrides)
    return AssistantAgent(
        name="area_chair",
        system_message=EDITOR_PROMPT,
        llm_config=llm_config,
    )

# %% [markdown]
# ## Read: we ask this new agent to make decisions according to human reviews
#
# Try this editor agent on a few paper submissions with human reviews, let's see if the editor can understand and make reasonable decisions according to the numan reviews.

# %%
NUM_PAPERS = 5
simulated_decisions = []
selected_list = ["d5HUnyByAI", "Q2bJ2qgcP1", "X9OfMNNepI", "hjROBHstZ3", "xXTkbTBmqq", "BpfsxFqhGa", "VsxbWTDHjh", "d8hYXbxX71", "dTPz4rEDok", "awvJBtB2op"]
other_paper_ids = list(set(df_ICLR_2025["paper_id"].tolist()) - set(selected_list))

sampled_paper_ids = list(np.random.choice(selected_list, size=NUM_PAPERS // 2, replace=False)) + list(np.random.choice(other_paper_ids, size=NUM_PAPERS - NUM_PAPERS // 2, replace=False))

for paper_id in tqdm(sampled_paper_ids, desc="Simulating decisions"):
    editor_agent = make_editor_agent()
    paper_data = df_ICLR_2025[df_ICLR_2025['paper_id'] == paper_id]
    actual_decision = paper_data['decision'].iloc[0]
    reviews = paper_data['review'].tolist()

    # Build the input message for the editor agent
    reviews_text = "\n\n---\n\n".join([f"Review {i+1}:\n{r}" for i, r in enumerate(reviews)])
    input_message = f"Please make a decision for this paper based on the following reviews:\n\n{reviews_text}"

    # Get simulated decision from the editor agent
    response = editor_agent.generate_reply(messages=[{"role": "user", "content": input_message}])

    # Record the result
    result = {
        "paper_id": paper_id,
        "actual_decision": actual_decision,
        "number_of_reviews": len(reviews),
        "simulated_response": response
    }
    simulated_decisions.append(result)

df_simulated = pd.DataFrame(simulated_decisions)
df_simulated
# Out:
# Simulating decisions:  40%|████      | 2/5 [00:00<00:01,  2.97it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[224], line 19
#      16 input_message = f"Please make a decision for this paper based on the following reviews:\n\n{reviews_text}"
#      18 # Get simulated decision from the editor agent
# ---> 19 response = editor_agent.generate_reply(messages=[{"role": "user", "content": input_message}])
#      21 # Record the result
#      22 result = {
#      23     "paper_id": paper_id,
#      24     "actual_decision": actual_decision,
#      25     "number_of_reviews": len(reviews),
#      26     "simulated_response": response
#      27 }
#
# File /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:2070, in ConversableAgent.generate_reply(self, messages, sender, **kwargs)
#    2068     continue
#    2069 if self._match_trigger(reply_func_tuple["trigger"], sender):
# -> 2070     final, reply = reply_func(self, messages=messages, sender=sender, config=reply_func_tuple["config"])
#    2071     if logging_enabled():
#    2072         log_event(
#    2073             self,
#    2074             "reply_func_executed",
#    (...)
#    2078             reply=reply,
#    2079         )
#
# File /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:1437, in ConversableAgent.generate_oai_reply(self, messages, sender, config)
#    1435 if messages is None:
#    1436     messages = self._oai_messages[sender]
# -> 1437 extracted_response = self._generate_oai_reply_from_client(
#    1438     client, self._oai_system_message + messages, self.client_cache
#    1439 )
#    1440 return (False, None) if extracted_response is None else (True, extracted_response)
#
# File /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:1456, in ConversableAgent._generate_oai_reply_from_client(self, llm_client, messages, cache)
#    1453         all_messages.append(message)
#    1455 # TODO: #1143 handle token limit exceeded error
# -> 1456 response = llm_client.create(
#    1457     context=messages[-1].pop("context", None), messages=all_messages, cache=cache, agent=self
#    1458 )
#    1459 extracted_response = llm_client.extract_text_or_completion_object(response)[0]
#    1461 if extracted_response is None:
#
# File /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages/autogen/oai/client.py:777, in OpenAIWrapper.create(self, **config)
#     775     self._throttle_api_calls(i)
#     776     request_ts = get_current_ts()
# --> 777     response = client.create(params)
#     778 except APITimeoutError as err:
#     779     logger.debug(f"config {i} timed out", exc_info=True)
#
# File /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages/autogen/oai/client.py:342, in OpenAIClient.create(self, params)
#     340     params = params.copy()
#     341     params["stream"] = False
# --> 342     response = completions.create(**params)
#     344 return response
#
# File /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages/openai/resources/chat/completions/completions.py:1156, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1110 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1111 def create(
#    1112     self,
#    (...)
#    1153     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1154 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1155     validate_response_format(response_format)
# -> 1156     return self._post(
#    1157         "/chat/completions",
#    1158         body=maybe_transform(
#    1159             {
#    1160                 "messages": messages,
#    1161                 "model": model,
#    1162                 "audio": audio,
#    1163                 "frequency_penalty": frequency_penalty,
#    1164                 "function_call": function_call,
#    1165                 "functions": functions,
#    1166                 "logit_bias": logit_bias,
#    1167                 "logprobs": logprobs,
#    1168                 "max_completion_tokens": max_completion_tokens,
#    1169                 "max_tokens": max_tokens,
#    1170                 "metadata": metadata,
#    1171                 "modalities": modalities,
#    1172                 "n": n,
#    1173                 "parallel_tool_calls": parallel_tool_calls,
#    1174                 "prediction": prediction,
#    1175                 "presence_penalty": presence_penalty,
#    1176                 "prompt_cache_key": prompt_cache_key,
#    1177                 "reasoning_effort": reasoning_effort,
#    1178                 "response_format": response_format,
#    1179                 "safety_identifier": safety_identifier,
#    1180                 "seed": seed,
#    1181                 "service_tier": service_tier,
#    1182                 "stop": stop,
#    1183                 "store": store,
#    1184                 "stream": stream,
#    1185                 "stream_options": stream_options,
#    1186                 "temperature": temperature,
#    1187                 "tool_choice": tool_choice,
#    1188                 "tools": tools,
#    1189                 "top_logprobs": top_logprobs,
#    1190                 "top_p": top_p,
#    1191                 "user": user,
#    1192                 "verbosity": verbosity,
#    1193                 "web_search_options": web_search_options,
#    1194             },
#    1195             completion_create_params.CompletionCreateParamsStreaming
#    1196             if stream
#    1197             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1198         ),
#    1199         options=make_request_options(
#    1200             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1201         ),
#    1202         cast_to=ChatCompletion,
#    1203         stream=stream or False,
#    1204         stream_cls=Stream[ChatCompletionChunk],
#    1205     )
#
# File /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)
#    1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages/openai/_base_client.py:982, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     980 response = None
#     981 try:
# --> 982     response = self._client.send(
#     983         request,
#     984         stream=stream or self._should_stream_response_body(request=request),
#     985         **kwargs,
#     986     )
#     987 except httpx.TimeoutException as err:
#     988     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File /opt/anaconda3/envs/llm-abm/lib/python3.10/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File /opt/anaconda3/envs/llm-abm/lib/python3.10/ssl.py:1292, in SSLSocket.recv(self, buflen, flags)
#    1288     if flags != 0:
#    1289         raise ValueError(
#    1290             "non-zero flags not allowed in calls to recv() on %s" %
#    1291             self.__class__)
# -> 1292     return self.read(buflen)
#    1293 else:
#    1294     return super().recv(buflen, flags)
#
# File /opt/anaconda3/envs/llm-abm/lib/python3.10/ssl.py:1165, in SSLSocket.read(self, len, buffer)
#    1163         return self._sslobj.read(len, buffer)
#    1164     else:
# -> 1165         return self._sslobj.read(len)
#    1166 except SSLError as x:
#    1167     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
# Examine a few reasoning examples from the simulated responses
for i, row in df_simulated.head(5).iterrows():
    print(f"[{i}] Paper ID: {row['paper_id']}")
    print(f"Actual Decision: {row['actual_decision']}")

    # Parse the decision and confidence from the simulated_response
    try:
        response_json = json.loads(row['simulated_response'])
        simulated_decision = response_json.get('decision', 'N/A')
        simulated_confidence = response_json.get('confidence', 'N/A')
        print(f"Simulated Decision: {simulated_decision}")
        print(f"Confidence: {simulated_confidence}")
        print("-" * 80)

        # Display the reasoning if available
        if 'rationale' in response_json:
            print(f"Rationale:\n{response_json['rationale']}")
        if 'highlights' in response_json:
            print(f"Highlights:")
            for highlight in response_json['highlights']:
                print(f"  - {highlight}")
    except (json.JSONDecodeError, TypeError):
        print(f"Simulated Decision: N/A (parse error)")
        print(f"Confidence: N/A (parse error)")
        print("-" * 80)
        print(f"Raw Response:\n{row['simulated_response']}")

    print("=" * 80)
    print()
# Out:
# [0] Paper ID: d5HUnyByAI
# Actual Decision: Accept (Poster)
# Simulated Decision: Reject
# Confidence: 0.75
# --------------------------------------------------------------------------------
# Rationale:
# While the paper presents a well-structured approach and demonstrates effective results in multimodal biological classification, it lacks methodological novelty and suffers from significant weaknesses. The reviewers reached a consensus that the methodological contributions are not substantial enough, often relying on standard techniques without introducing new representation learning advancements. Several reviewers pointed out misunderstandings regarding the use of DNA barcodes as a superior modality and raised concerns about the limitations of the dataset used, the absence of comprehensive baselines, and the assumptions made during inference on unseen species. These issues indicate that the fundamental claims of the manuscript are questionable, and thus, while the approach has merit, it does not meet the standards for acceptance at ICLR.
# Highlights:
#   - Lack of methodological novelty and reliance on established techniques
#   - Concerns regarding the assumptions made for unseen species inference
#   - Agreement among reviewers about limitations of dataset and baselines
#   - Significant technical inaccuracies leading to questionable claims and results
# ================================================================================
#
# [1] Paper ID: hjROBHstZ3
# Actual Decision: Accept (Poster)
# Simulated Decision: Reject
# Confidence: 0.85
# --------------------------------------------------------------------------------
# Rationale:
# The paper proposes a novel method for causal graph discovery from multiview data, which is well-motivated and addresses important biomedical applications. However, several major concerns arise, particularly regarding the theoretical foundations and practical applicability of the method. Multiple reviewers identified serious issues with the proofs and results of theorems, including confusion between identification and estimation, unclear assumptions, and a lack of clarity in the mathematical formulation. Furthermore, empirical evaluations do not convincingly demonstrate the method's effectiveness across more complex and realistic datasets. Despite some strengths highlighted across reviews, the consensus points to significant flaws in theory and practice that cannot be overlooked. Due to these issues, the paper does not meet the acceptance criteria for ICLR.
# Highlights:
#   - Major concerns regarding the accuracy and clarity of theoretical foundations, particularly in the proofs and claims of identification.
#   - Substantial issues identified with the lack of clarity in assumptions and the practical scalability of the proposed method.
#   - Concerns about the empirical evaluations and their applicability to real-world scenarios.
#   - While the motivation and writing are strong, fundamental issues must be addressed before this work can be accepted.
# ================================================================================
#
# [2] Paper ID: fyl82vAale
# Actual Decision: Reject
# Simulated Decision: Reject
# Confidence: 0.75
# --------------------------------------------------------------------------------
# Rationale:
# The paper proposes SOR-Mamba to mitigate sequential order bias in time series data, which is a relevant problem. However, there is significant consensus among reviewers about the limited technical novelty of the proposed methods, such as the regularization strategy and the removal of 1D-convolution, which lacks compelling justification. Experimental results show only marginal improvements and often appear inadequate when contrasted with state-of-the-art models. Additionally, reviewers highlighted issues such as insufficient comparisons with established baselines, vague descriptions of methodology, and unclear motivation for some choices made in the architecture. These major concerns collectively outweigh the paper's strengths in clarity and experimentation.
# Highlights:
#   - Clear consensus on limited novelty and justification of architectural changes
#   - Experimental results show only modest improvements, raising concerns about significance
#   - Majority agreement on the need for more comprehensive evaluations against existing baselines
#   - Lack of clarity in methodology and justification detracts from overall quality
# ================================================================================
#
# [3] Paper ID: UW0zetsx8X
# Actual Decision: Reject
# Simulated Decision: Reject
# Confidence: 0.75
# --------------------------------------------------------------------------------
# Rationale:
# The paper presents a novel approach to prompt optimization using human preference feedback, but faces fundamental issues. Reviewers commonly expressed concerns about the oversimplification of user preferences and the dependencies on human feedback which could limit the method's applicability in changing contexts. Additionally, substantial methodological flaws were noted, such as inadequate comparisons with existing state-of-the-art methods and ambiguity in prompt generation details. These concerns suggest that while the approach has some merit, its current formulation is not robust enough for acceptance.
# Highlights:
#   - Major consensus on the oversimplification of user preferences and the limitations of binary feedback.
#   - Disagreement on the effectiveness and comparison to alternative methods, with one reviewer emphasizing the lack of comparison to existing techniques.
#   - Significant concerns about methodological issues, including a lack of detail in prompt generation and dependencies on neural networks for selection.
#   - The need for more rigorous validation with varied tasks and scenarios was highlighted.
# ================================================================================
#
# [4] Paper ID: LuGHbK8qTa
# Actual Decision: Accept (Poster)
# Simulated Decision: Accept (Poster)
# Confidence: 0.75
# --------------------------------------------------------------------------------
# Rationale:
# The paper demonstrates a novel framework for reconstructing dynamic meshes from monocular videos, achieving substantial advancements in both mesh quality and rendering through innovative use of Gaussian-Mesh anchoring. There is a consensus among reviewers on the novelty and clarity of the approach, with strong performance results presented. However, significant concerns regarding the quantitative validation of critical design choices and the practical application of the method in real-world scenarios were raised, suggesting methodological gaps that need addressing. The reviewers suggest more thorough evaluations against additional baselines, clearer articulation of color extraction processes, and potential ambiguities regarding the handling of meshes versus Gaussian representations. While the identified weaknesses are notable, they do not overshadow the overall contributions and potential impact of the work, warranting acceptance as a poster for further discussions and improvements.
# Highlights:
#   - Innovative Gaussian-Mesh anchoring method shows strong promise for dynamic mesh reconstruction
#   - Significant improvement in rendering quality noted by multiple reviewers
#   - Concerns about quantitative evaluations and applicability in real-world settings
#   - Potential for methodological refinements, particularly in baseline comparisons and color handling
# ================================================================================

# %% [markdown]
# ### Limitation: the editor agent here is only making decision based on the first round reviews, and it does not have access to the paper text yet (due to computational cost to parse these PDFs).

# %% [markdown]
# # Just run: Building the LLM Reviewer Agents
#
# Configure synthetic reviewers by selecting their domain expertise and seniority. The selections here determine which AI reviewer personas will be generated in the next step.

# %% [markdown]
# ## Just run: Build Review Agents & Generate Reviews

# %% [markdown]
# ### Just run: Seniorities

# %%
AI_PANEL_ROWS: List[Dict[str, Any]] = []
AI_PANEL_STATE: List[Dict[str, str]] = []

# Level of seniority for AI reviewers.
SENIORITY_OPTIONS_ALLOWED = [
    "Graduate student",
    "Junior faculty",
    "Senior faculty",
    "random",  # let the system randomly pick one from the list.
]

# Domain of expertise for AI reviewers.
DOMAIN_OPTIONS = [
    "same",  # use the same domain as the paper.
    "random_different",  # let the system randomly pick one from the list of domains AVAILABLE_DOMAINS that is different from the paper's domain.
    # You can customize the AVAILABLE_DOMAINS variable above to include more domains or remove some domains.
]

# %% [markdown]
# ### Just run: Reviewer Building Helper

# %%
# Generate ReviewerPersona objects from the AI panel configuration.
# This function resolves "same"/"random_different" domain settings and "random" seniority
# to create concrete reviewer personas with specific expertise and seniority levels.

@dataclass
class ReviewerPersona:
    name: str
    expertise: str
    seniority: str

    def __post_init__(self):
        if self.seniority not in SENIORITY_OPTIONS_ALLOWED[:-1]:  # Exclude "random"
            raise ValueError(
                f"Invalid seniority '{self.seniority}'. "
                f"Must be one of: {SENIORITY_OPTIONS_ALLOWED[:-1]}"
            )
        if self.expertise not in AVAILABLE_DOMAINS:
            raise ValueError(
                f"Invalid expertise '{self.expertise}'. "
                f"Must be one of: {AVAILABLE_DOMAINS}"
            )

def create_reviewer_personas_from_state(
    panel_state: List[Dict[str, str]],
    paper_domain: str,
    available_domains: List[str] = AVAILABLE_DOMAINS,
    seniority_options: List[str] = SENIORITY_OPTIONS_ALLOWED[:-1],  # Exclude "random"
) -> List[ReviewerPersona]:
    """
    Create a list of ReviewerPersona objects from the AI_PANEL_STATE configuration.

    Args:
        panel_state: List of dicts with "domain" and "seniority" keys.
        paper_domain: The domain of the paper being reviewed.
        available_domains: List of available domains to choose from.
        seniority_options: List of valid seniority levels (excluding "random").

    Returns:
        List of ReviewerPersona objects.
    """
    personas = []

    for i, config in enumerate(panel_state):
        # Resolve domain
        domain = config.get("domain", "same")
        if domain == "same":
            expertise = paper_domain
        elif domain == "random_different":
            different_domains = [d for d in available_domains if d != paper_domain]
            expertise = random.choice(different_domains) if different_domains else paper_domain
        else:
            expertise = domain  # Use the specified domain directly

        # Resolve seniority
        seniority = config.get("seniority", "random")
        if seniority == "random":
            seniority = random.choice(seniority_options)

        persona = ReviewerPersona(
            name=f"AI Reviewer_{i + 1}: {seniority} in {expertise}",
            expertise=expertise,
            seniority=seniority,
        )
        personas.append(persona)

    return personas

def make_reviewer_agent(persona: ReviewerPersona) -> AssistantAgent:
    llm_config = build_llm_config()
    system_message = REVIEWER_PROMPT_TEMPLATE.format(
        expertise=persona.expertise,
        seniority=persona.seniority,
    )
    return AssistantAgent(
        name=persona.name,
        system_message=system_message,
        llm_config=llm_config,
    )

# %%
REVIEWER_PROMPT_TEMPLATE = """Your task is to compose a high-quality review for the top-tier Machine Learning (ML) conference International Conference on Learning Representations (ICLR).

You are a {seniority} and an expert in {expertise}.

A review aims to determine whether a submission will bring sufficient value to the community and contribute new knowledge. The process can be broken down into the following main reviewer tasks:

* Read the paper: It's important to carefully read through the entire paper, and to consider any related work and citations that will help you comprehensively evaluate it. While reading, consider the following:
  * Objective of the work: What is the goal of the paper? Is it to better address a known application or problem, draw attention to a new application or problem, or to introduce and/or explain a new theoretical finding? A combination of these? Different objectives will require different considerations as to potential value and impact.
  * Is the approach well motivated, including being well-placed in the literature?
  * Does the paper support the claims? This includes determining if results, whether theoretical or empirical, are correct and if they are scientifically rigorous.
  * What is the significance of the work? Does it contribute new knowledge and sufficient value to the community? Note, this does not necessarily require state-of-the-art results. Submissions bring value to the ICLR community when they convincingly demonstrate new, relevant, impactful knowledge (incl., empirical, theoretical, for practitioners, etc).

* Write and submit your initial review, organizing it as follows:
  * summary: Summarize what the paper claims to contribute. What is the specific question and/or problem tackled by the paper? Be positive and constructive.
  * strengths: List strong points of the paper: is the submission clear, technically correct, experimentally rigorous, reproducible, does it present novel findings (e.g. theoretically, algorithmically, etc.)? Be as comprehensive, specific, and detailed as possible.
  * weaknesses: List weak points of the paper: is it weak in any of the aspects listed in the previous point? Be as comprehensive, specific, and detailed as possible.
  * questions: Ask questions you would like answered by the authors to help you clarify your understanding of the paper and provide the additional evidence you need to be confident in your assessment.
  * rating: A numeric evaluation of the paper, chosen from the following:
    * 10: strong accept, should be highlighted at the conference
    * 8: accept, good paper
    * 6: marginally above the acceptance threshold
    * 5: marginally below the acceptance threshold
    * 3: reject, not good enough
  * confidence: how confident you are in your assessment. It should be an integer chosen from: 2, 3, 4, or 5, based on the following descriptions:
    * 5: You are absolutely certain about your assessment. You are very familiar with the related work and checked the math/other details carefully.
    * 4: You are confident in your assessment, but not absolutely certain. It is unlikely, but not impossible, that you did not understand some parts of the submission or that you are unfamiliar with some pieces of related work.
    * 3: You are fairly confident in your assessment. It is possible that you did not understand some parts of the submission or that you are unfamiliar with some pieces of related work. Math/other details were not carefully checked.
    * 2: You are willing to defend your assessment, but it is quite likely that you did not understand the central parts of the submission or that you are unfamiliar with some pieces of related work. Math/other details were not carefully checked.

To reiterate, you are a {seniority} and an expert in {expertise}.

Final guidelines:
* Provide a fair, evidence-based review using first person plural.
* Produce exactly one JSON object as specified below; do not add commentary or prose outside JSON.

JSON schema (keys are required):
{{
  "persona": {{"expertise": string, "seniority": string}},
  "review": {{
    "summary": [string],
    "strengths": [string],
    "weaknesses": [string],
    "questions": [string],
    "rating": integer 3-10,
    "confidence": integer 2-5
  }}
}}
"""
print(REVIEWER_PROMPT_TEMPLATE)
# Out:
# Your task is to compose a high-quality review for the top-tier Machine Learning (ML) conference International Conference on Learning Representations (ICLR).
#
# You are a {seniority} and an expert in {expertise}.
#
# A review aims to determine whether a submission will bring sufficient value to the community and contribute new knowledge. The process can be broken down into the following main reviewer tasks:
#
# * Read the paper: It's important to carefully read through the entire paper, and to consider any related work and citations that will help you comprehensively evaluate it. While reading, consider the following:
#   * Objective of the work: What is the goal of the paper? Is it to better address a known application or problem, draw attention to a new application or problem, or to introduce and/or explain a new theoretical finding? A combination of these? Different objectives will require different considerations as to potential value and impact.
#   * Is the approach well motivated, including being well-placed in the literature?
#   * Does the paper support the claims? This includes determining if results, whether theoretical or empirical, are correct and if they are scientifically rigorous.
#   * What is the significance of the work? Does it contribute new knowledge and sufficient value to the community? Note, this does not necessarily require state-of-the-art results. Submissions bring value to the ICLR community when they convincingly demonstrate new, relevant, impactful knowledge (incl., empirical, theoretical, for practitioners, etc).
#
# * Write and submit your initial review, organizing it as follows:
#   * summary: Summarize what the paper claims to contribute. What is the specific question and/or problem tackled by the paper? Be positive and constructive.
#   * strengths: List strong points of the paper: is the submission clear, technically correct, experimentally rigorous, reproducible, does it present novel findings (e.g. theoretically, algorithmically, etc.)? Be as comprehensive, specific, and detailed as possible.
#   * weaknesses: List weak points of the paper: is it weak in any of the aspects listed in the previous point? Be as comprehensive, specific, and detailed as possible.
#   * questions: Ask questions you would like answered by the authors to help you clarify your understanding of the paper and provide the additional evidence you need to be confident in your assessment.
#   * rating: A numeric evaluation of the paper, chosen from the following:
#     * 10: strong accept, should be highlighted at the conference
#     * 8: accept, good paper
#     * 6: marginally above the acceptance threshold
#     * 5: marginally below the acceptance threshold
#     * 3: reject, not good enough
#   * confidence: how confident you are in your assessment. It should be an integer chosen from: 2, 3, 4, or 5, based on the following descriptions:
#     * 5: You are absolutely certain about your assessment. You are very familiar with the related work and checked the math/other details carefully.
#     * 4: You are confident in your assessment, but not absolutely certain. It is unlikely, but not impossible, that you did not understand some parts of the submission or that you are unfamiliar with some pieces of related work.
#     * 3: You are fairly confident in your assessment. It is possible that you did not understand some parts of the submission or that you are unfamiliar with some pieces of related work. Math/other details were not carefully checked.
#     * 2: You are willing to defend your assessment, but it is quite likely that you did not understand the central parts of the submission or that you are unfamiliar with some pieces of related work. Math/other details were not carefully checked.
#
# To reiterate, you are a {seniority} and an expert in {expertise}.
#
# Final guidelines:
# * Provide a fair, evidence-based review using first person plural.
# * Produce exactly one JSON object as specified below; do not add commentary or prose outside JSON.
#
# JSON schema (keys are required):
# {{
#   "persona": {{"expertise": string, "seniority": string}},
#   "review": {{
#     "summary": [string],
#     "strengths": [string],
#     "weaknesses": [string],
#     "questions": [string],
#     "rating": integer 3-10,
#     "confidence": integer 2-5
#   }}
# }}

# %% [markdown]
# ### Just run: Build Reviewers

# %%
# Get personas
personas = create_reviewer_personas_from_state(AI_PANEL_STATE, PAPER_DOMAIN)

# create LLM reviewer agents
AI_REVIEWERS = [make_reviewer_agent(persona) for persona in personas]

# %%
personas
# Out:
# [ReviewerPersona(name='AI Reviewer_1: Graduate student in Causality', expertise='Causality', seniority='Graduate student'),
#  ReviewerPersona(name='AI Reviewer_2: Junior faculty in Causality', expertise='Causality', seniority='Junior faculty'),
#  ReviewerPersona(name='AI Reviewer_3: Senior faculty in Causality', expertise='Causality', seniority='Senior faculty'),
#  ReviewerPersona(name='AI Reviewer_4: Senior faculty in Causality', expertise='Causality', seniority='Senior faculty'),
#  ReviewerPersona(name='AI Reviewer_5: Senior faculty in Multimodal Learning', expertise='Multimodal Learning', seniority='Senior faculty')]

# %%
AI_REVIEWERS
# Out:
# [<autogen.agentchat.assistant_agent.AssistantAgent at 0x1b4abfdc0>,
#  <autogen.agentchat.assistant_agent.AssistantAgent at 0x1b4873ac0>,
#  <autogen.agentchat.assistant_agent.AssistantAgent at 0x1b463fee0>,
#  <autogen.agentchat.assistant_agent.AssistantAgent at 0x1b4b17340>,
#  <autogen.agentchat.assistant_agent.AssistantAgent at 0x1b4b17ac0>]

# %% [markdown]
# ### Just run: Generate Reviews

# %%
# Helper utilities for AI review records and scoring

def flatten_review_text_ai(record: Union[Dict[str, Any], str]) -> str:
    """Flatten AI review record to text."""
    if isinstance(record, str):
        return record
    if isinstance(record, dict):
        text_value = record.get("text")
        if isinstance(text_value, str) and text_value.strip():
            return text_value
        response = record.get("response", "")
    else:
        response = record
    if isinstance(response, str):
        return response
    if isinstance(response, dict):
        parts = []
        for key in ("summary", "strengths", "weaknesses", "questions"):
            value = response.get(key, "")
            if isinstance(value, str):
                parts.append(value)
            elif isinstance(value, list):
                parts.extend([str(v) for v in value])
        return "\n".join(parts)
    return str(response)

def score_ai_review_records(
    records: List[Dict[str, Any]],
    source_label: str = "AI",
    num_trials: int = 1,
    model: str = DEFAULT_LLM_CONFIG["model"],
) -> List[Dict[str, Any]]:
    """Score AI review records using aspects_of_comments."""
    scored: List[Dict[str, Any]] = []
    if not records:
        return scored
    for idx, record in enumerate(records, start=1):
        persona = record.get("persona", {})
        review_text = flatten_review_text_ai(record)
        if not review_text:
            continue
        scores = aspects_of_comments(review_text, model=model, num_trials=num_trials)
        scored.append(
            {
                "source": source_label,
                "name": persona.get("name", f"{source_label}_{idx}"),
                "domain": persona.get("expertise", PAPER_DOMAIN),
                "seniority": persona.get("seniority", "unknown"),
                "reviewer": persona.get("name", f"{source_label}_{idx}"),
                **scores,
            }
        )
    return scored

def build_persona_lookup(persona_list: Sequence[ReviewerPersona]) -> Dict[str, ReviewerPersona]:
    """Create a name -> persona mapping for quick lookups."""
    return {persona.name: persona for persona in persona_list}

def infer_persona_metadata(reviewer_name: str, default_domain: str) -> Tuple[str, str]:
    """Infer expertise and seniority from the reviewer label when persona data is missing."""
    seniority = "unknown"
    if "Graduate student" in reviewer_name:
        seniority = "Graduate student"
    elif "Junior faculty" in reviewer_name:
        seniority = "Junior faculty"
    elif "Senior faculty" in reviewer_name:
        seniority = "Senior faculty"

    expertise = default_domain
    if " in " in reviewer_name:
        expertise = reviewer_name.split(" in ")[-1]
    return expertise, seniority

def tag_ai_reviews(
    ai_reviews: Sequence[Dict[str, Any]],
    persona_lookup: Dict[str, ReviewerPersona],
    paper_domain: str,
) -> List[Dict[str, Any]]:
    """Attach persona metadata, domain source, and flattened text to each AI review."""
    tagged: List[Dict[str, Any]] = []
    for idx, review in enumerate(ai_reviews, start=1):
        reviewer_name = review.get("reviewer", f"ai_reviewer_{idx}")
        persona_obj = persona_lookup.get(reviewer_name)
        if persona_obj:
            expertise = persona_obj.expertise
            seniority = persona_obj.seniority
        else:
            expertise, seniority = infer_persona_metadata(reviewer_name, paper_domain)
        domain_source = "same" if expertise == paper_domain else "random_different"
        response = review.get("response", "")
        tagged.append(
            {
                "reviewer": reviewer_name,
                "persona": {
                    "name": reviewer_name,
                    "expertise": expertise,
                    "seniority": seniority,
                },
                "domain_source": domain_source,
                "response": response,
                "text": flatten_review_text_ai(review),
            }
        )
    return tagged

# %% [markdown]
# # Run & Read: Generate AI reviewer reviews on your selected paper
#
# Click the button below to synthesize reviews for each configured AI persona.

# %%
AI_REVIEWS: List[Dict[str, Any]] = []


def generate_ai_reviews():
    """Generate AI reviews for the paper using configured reviewer personas."""
    global AI_REVIEWS

    if not AI_REVIEWERS:
        print("No AI reviewers configured. Please set up reviewer personas first.")
        return

    print(f"Generating {len(AI_REVIEWERS)} AI reviews …")
    start = time.perf_counter()
    generated: List[Dict[str, Any]] = []

    for reviewer in AI_REVIEWERS:
        try:
            response = reviewer.generate_reply(
                messages=[{"role": "user", "content": PAPER_TEXT}]
            )
            generated.append({
                "reviewer": reviewer.name,
                "response": response,
            })
            print(f"✓ {reviewer.name}")
        except Exception as exc:
            print(f"✗ {reviewer.name}: {exc}")

    AI_REVIEWS = generated
    elapsed = time.perf_counter() - start
    print(f"Completed in {elapsed:.1f}s. Generated {len(AI_REVIEWS)} reviews.")

    for review in AI_REVIEWS:
        print(f"\n--- {review['reviewer']} ---")
        print(review['response'])


# Run the generation
generate_ai_reviews()
# Out:
# Generating 5 AI reviews …
# ✓ AI Reviewer_1: Graduate student in Causality
# ✓ AI Reviewer_2: Junior faculty in Causality
# ✓ AI Reviewer_3: Senior faculty in Causality
# ✓ AI Reviewer_4: Senior faculty in Causality
# ✓ AI Reviewer_5: Senior faculty in Video Understanding
# Completed in 11.1s. Generated 5 reviews.
#
# --- AI Reviewer_1: Graduate student in Causality ---
# {
#   "persona": {
#     "expertise": "Causality",
#     "seniority": "Graduate student"
#   },
#   "review": {
#     "summary": [
#       "The paper addresses the critical issue of the effectiveness of modern Conditional Average Treatment Effect (CATE) estimation models by conducting a comprehensive benchmark evaluation on their performance with real-world datasets. Highlighting that a significant portion of these models produce degenerate estimators and fail to outperform trivial baselines, the authors introduce novel metrics and a new methodological framework for evaluating CATE models. The empirical findings shed light on the inability of current models to adequately capture real-world heterogeneity and call for improved evaluation practices and model development."
#     ],
#     "strengths": [
#       "The paper presents a large-scale benchmarking study evaluating 16 contemporary CATE models across a diverse set of real-world datasets, which is a significant contribution to the field of causal inference.",
#       "The introduction of a novel evaluation metric (Q) provides a new perspective on CATE model performance that captures real-world heterogeneity and does not rely on counterfactual ground truth, addressing a long-standing limitation in the literature.",
#       "The comprehensive analysis and clear presentation of results, including the comparison of CATE models and their performance metrics, enhance the reproducibility and rigor of the evaluation.",
#       "By using observational sampling, the authors effectively demonstrate an innovative approach that combines both training on biased data and evaluation on unbiased data, which could improve model evaluation practices in causal inference."
#     ],
#     "weaknesses": [
#       "While the results are compelling, the paper predominantly discusses limitations observed in existing models without proposing specific actionable steps for developers to improve their methodologies, which could enhance the practical applicability of the findings.",
#       "The lack of deep exploration into the underlying reasons why certain models performed poorly could be seen as a missed opportunity to provide more insight into model development for practitioners.",
#       "Some readers may find sections of the paper that are heavily mathematical difficult to follow, which could limit accessibility to a broader audience not specialized in causal inference."
#     ],
#     "questions": [
#       "How do you envision the future directions for improving CATE models based on your findings? Are there specific methodologies or adjustments that you would suggest?",
#       "Can you elaborate on the implications of the findings regarding orthogonality-based methods? What specific modeling choices led to their underperformance?",
#       "How generalizable are your methods and results to other domains beyond those studied in this benchmark?"
#     ],
#     "rating": 8,
#     "confidence": 4
#   }
# }
#
# --- AI Reviewer_2: Junior faculty in Causality ---
# ```json
# {
#   "persona": {
#     "expertise": "Causality",
#     "seniority": "Junior faculty"
#   },
#   "review": {
#     "summary": [
#       "The paper presents a large-scale benchmark study evaluating conditional average treatment effect (CATE) estimation algorithms. It finds that many current CATE models perform poorly in capturing real-world heterogeneity, with a significant proportion yielding negligible results compared to trivial estimators.",
#       "The authors introduce a novel evaluation metric, Q, which helps assess CATE models in practical scenarios without the need for counterfactual outcomes."
#     ],
#     "strengths": [
#       "The research addresses a critical topic in causal inference and provides empirical evidence that raises important questions about the efficacy of existing CATE models.",
#       "The novel approach of observational sampling combined with the proposed Q statistic provides a significant contribution to the methodology for CATE evaluation.",
#       "The benchmark's reliance on real-world datasets enhances the validity of the findings compared to previous studies predominantly using simulated outcomes.",
#       "The large scale of the study (16 models on 12 datasets with 43,200 sampled variants) contributes to the robustness of the results."
#     ],
#     "weaknesses": [
#       "The threshold of model effectiveness is primarily determined by comparison against trivial and constant-effect estimators, which may not fully capture the nuances of practical applications in various fields.",
#       "The findings indicate a systemic issue in model performance, but further investigation is needed on why these weaknesses exist and what practical steps can be taken to improve performance.",
#       "The paper could benefit from additional discussion on the implications of the findings for practitioners and future research directions."
#     ],
#     "questions": [
#       "How do the authors suggest practitioners should adapt their choice of CATE models in light of the findings?",
#       "Could the authors provide a more detailed analysis of how the proposed metric Q compares to existing evaluation methods in terms of areas such as variance and bias?",
#       "What are the implications of the findings for ongoing and future work in the CATE estimation landscape?"
#     ],
#     "rating": 8,
#     "confidence": 4
#   }
# }
# ```
#
# --- AI Reviewer_3: Senior faculty in Causality ---
# {
#   "persona": {"expertise": "Causality", "seniority": "Senior faculty"},
#   "review": {
#     "summary": [
#       "The paper presents a rigorous investigation into the effectiveness of contemporary Conditional Average Treatment Effect (CATE) estimation models through a large-scale benchmark study, highlighting significant shortcomings in their capacity to capture real-world heterogeneity."
#     ],
#     "strengths": [
#       "The study employs a comprehensive evaluation framework utilizing 12 real-world datasets and 43,200 sampled variants, which is a substantial size that enhances the reliability of results.",
#       "Introduction of the statistical parameter Q provides a novel approach to assess CATE estimation models without requiring counterfactual ground truth, addressing a fundamental limitation in the field.",
#       "The findings are backed by methodologically sound statistical rigor, including the use of mean squared error (MSE) to demonstrate the underperformance of many CATE models relative to trivial benchmarks.",
#       "The results provide valuable insights into the limitations of existing CATE models, prompting necessary discussions on potential improvements and future research directions.",
#       "The focus on observational sampling methods for model evaluation is a refreshing contribution that encourages a reevaluation of conventional evaluation practices in the field of causal inference."
#     ],
#     "weaknesses": [
#       "While comprehensive, the limitations of the datasets used should be explicitly addressed—namely, how they may not represent all potential real-world scenarios, potentially skewing the generalizability of findings.",
#       "The discussion around alternative modeling strategies or adjustments is somewhat limited; more specific recommendations for addressing the identified weaknesses in CATE models could enhance the practicality of the conclusions.",
#       "The paper assumes that the performance of CATE models evaluated in this study will reliably predict performance in other contexts, which may not always hold true due to varying underlying data-generating processes."
#     ],
#     "questions": [
#       "How do the findings from this benchmark study translate to specific applications in fields like healthcare or economics where CATE models are frequently deployed?",
#       "Can the proposed statistical parameter Q be generalized beyond the specified experimental frameworks, and what implications would this have for causal inference at large?",
#       "What specific steps could practitioners take to mitigate the risks identified in the benchmark results, particularly regarding model selection and implementation?"
#     ],
#     "rating": 8,
#     "confidence": 4
#   }
# }
#
# --- AI Reviewer_4: Senior faculty in Causality ---
# {
#   "persona": {"expertise": "Causality", "seniority": "Senior faculty"},
#   "review": {
#     "summary": [
#       "The paper presents a rigorous investigation into the effectiveness of contemporary Conditional Average Treatment Effect (CATE) estimation models through a large-scale benchmark study, highlighting significant shortcomings in their capacity to capture real-world heterogeneity."
#     ],
#     "strengths": [
#       "The study employs a comprehensive evaluation framework utilizing 12 real-world datasets and 43,200 sampled variants, which is a substantial size that enhances the reliability of results.",
#       "Introduction of the statistical parameter Q provides a novel approach to assess CATE estimation models without requiring counterfactual ground truth, addressing a fundamental limitation in the field.",
#       "The findings are backed by methodologically sound statistical rigor, including the use of mean squared error (MSE) to demonstrate the underperformance of many CATE models relative to trivial benchmarks.",
#       "The results provide valuable insights into the limitations of existing CATE models, prompting necessary discussions on potential improvements and future research directions.",
#       "The focus on observational sampling methods for model evaluation is a refreshing contribution that encourages a reevaluation of conventional evaluation practices in the field of causal inference."
#     ],
#     "weaknesses": [
#       "While comprehensive, the limitations of the datasets used should be explicitly addressed—namely, how they may not represent all potential real-world scenarios, potentially skewing the generalizability of findings.",
#       "The discussion around alternative modeling strategies or adjustments is somewhat limited; more specific recommendations for addressing the identified weaknesses in CATE models could enhance the practicality of the conclusions.",
#       "The paper assumes that the performance of CATE models evaluated in this study will reliably predict performance in other contexts, which may not always hold true due to varying underlying data-generating processes."
#     ],
#     "questions": [
#       "How do the findings from this benchmark study translate to specific applications in fields like healthcare or economics where CATE models are frequently deployed?",
#       "Can the proposed statistical parameter Q be generalized beyond the specified experimental frameworks, and what implications would this have for causal inference at large?",
#       "What specific steps could practitioners take to mitigate the risks identified in the benchmark results, particularly regarding model selection and implementation?"
#     ],
#     "rating": 8,
#     "confidence": 4
#   }
# }
#
# --- AI Reviewer_5: Senior faculty in Video Understanding ---
# ```json
# {
#   "persona": {
#     "expertise": "Video Understanding",
#     "seniority": "Senior Faculty"
#   },
#   "review": {
#     "summary": [
#       "The paper presents a large-scale benchmark study of Conditional Average Treatment Effect (CATE) estimation models, revealing critical insights into their performance in capturing real-world heterogeneity. It introduces a new metric, Q, aimed at providing a robust evaluation of CATE models against trivial benchmarks, demonstrating that many contemporary CATE models often fall short of expectations."
#     ],
#     "strengths": [
#       "The approach is well-motivated and timely, addressing a significant gap in the evaluation of CATE models, particularly in real-world scenarios.",
#       "The authors employ a large and diverse dataset, significantly larger than typical benchmarks, enhancing the reliability and impact of their findings.",
#       "Development and introduction of the statistical parameter Q, which allows for a clearer and more robust evaluation of CATE models without the need for counterfactuals, which is a notable methodological advancement.",
#       "The empirical results are surprising and insightful, effectively communicating the limitations of current CATE models and encouraging further investigation into practical evaluation criteria.",
#       "The paper is well-organized and clearly written, making complex concepts accessible while maintaining technical rigor."
#     ],
#     "weaknesses": [
#       "While the findings are certainly impactful, the paper could benefit from a more detailed discussion of the implications for the design and selection of CATE models in practice.",
#       "The authors do not explore the potential for other evaluation methods or models that could complement or improve their proposed evaluation framework.",
#       "The paper primarily critiques existing models rather than proposing new modeling approaches, which may limit its direct applicability to practitioners seeking new solutions.",
#       "Further elaboration is needed on the variance reduction techniques for the Q statistic, particularly how they can be implemented in practice."
#     ],
#     "questions": [
#       "Can the authors discuss the broader implications of their findings for practitioners using CATE models in high-stakes decision-making?",
#       "In what ways do they envision the future landscape of CATE model evaluation evolving based on their findings?",
#       "What specific steps do the authors recommend for researchers to improve the robustness of CATE estimation moving forward, considering the limitations outlined?"
#     ],
#     "rating": 8,
#     "confidence": 4
#   }
# }
# ```

# %% [markdown]
# ## Read: Quickly Analyze the LLM Reviewer Agents's Reviews

# %%
for review in AI_REVIEWS:
    print(f"\n--- {review['reviewer']} ---")
    summary = text_summary(review['response'])
    print(summary)
# Out:
# --- AI Reviewer_1: Graduate student in Causality ---
# 16 sentences, 391 words, ~0.8 pages (double-spaced)
#
# --- AI Reviewer_2: Junior faculty in Causality ---
# 14 sentences, 319 words, ~0.6 pages (double-spaced)
#
# --- AI Reviewer_3: Senior faculty in Causality ---
# 13 sentences, 348 words, ~0.7 pages (double-spaced)
#
# --- AI Reviewer_4: Senior faculty in Causality ---
# 13 sentences, 348 words, ~0.7 pages (double-spaced)
#
# --- AI Reviewer_5: Senior faculty in Video Understanding ---
# 15 sentences, 348 words, ~0.7 pages (double-spaced)

# %%
# Build AI review records from AI_REVIEWS for scoring
persona_lookup = build_persona_lookup(personas)
tagged_ai_reviews = tag_ai_reviews(AI_REVIEWS, persona_lookup, PAPER_DOMAIN)

ai_review_records = [
    {"persona": tagged["persona"], "response": tagged["response"]}
    for tagged in tagged_ai_reviews
]

# Score the AI reviews
ai_scored = score_ai_review_records(ai_review_records, source_label="AI")

# Combine with human scores if available
if 'ASPECT_SCORES_DF' in dir() and ASPECT_SCORES_DF is not None:
    ai_scores_df = pd.DataFrame(ai_scored)
    ASPECT_SCORES_DF = pd.concat([ASPECT_SCORES_DF, ai_scores_df], ignore_index=True)
else:
    ASPECT_SCORES_DF = pd.DataFrame(ai_scored)

AI_REVIEW_TEXTS = [tagged["text"] for tagged in tagged_ai_reviews if tagged.get("text")]

# Create histogram comparing distribution of topics that AI and human reviewers care about

# Define the aspect columns
aspect_cols = ['accuracy', 'clarity', 'consistency', 'novelty', 'replicability', 'thoroughness', 'positive', 'negative']

# Separate human and AI scores
human_scores = ASPECT_SCORES_DF[ASPECT_SCORES_DF['source'] == 'human'][aspect_cols]
ai_scores = ASPECT_SCORES_DF[ASPECT_SCORES_DF['source'] == 'AI'][aspect_cols]

# Calculate mean scores for each aspect
human_means = human_scores.mean()
ai_means = ai_scores.mean()

# Calculate standard errors for error bars
human_stds = human_scores.std()
ai_stds = ai_scores.std()
human_sems = human_stds / np.sqrt(len(human_scores))
ai_sems = ai_stds / np.sqrt(len(ai_scores))

# Create the histogram comparison
fig, ax = plt.subplots(figsize=(12, 6))

x = np.arange(len(aspect_cols))
width = 0.35

bars_human = ax.bar(x - width/2, human_means.values, width, label='Human Reviewers',
                    color='steelblue', alpha=0.8, yerr=human_sems.values, capsize=4)
bars_ai = ax.bar(x + width/2, ai_means.values, width, label='AI Reviewers',
                 color='coral', alpha=0.8, yerr=ai_sems.values, capsize=4)

ax.set_xlabel('Review Aspects', fontsize=12)
ax.set_ylabel('Mean Score', fontsize=12)
ax.set_title('Distribution of Topics/Aspects: Human vs AI Reviewers', fontsize=14)
ax.set_xticks(x)
ax.set_xticklabels([col.capitalize() for col in aspect_cols], rotation=45, ha='right')
ax.legend()

# Add value labels on bars
for bar in bars_human:
    height = bar.get_height()
    ax.annotate(f'{height:.3f}',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom', fontsize=8)

for bar in bars_ai:
    height = bar.get_height()
    ax.annotate(f'{height:.3f}',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom', fontsize=8)

plt.tight_layout()
plt.show()

# Print summary statistics
print("\nSummary Statistics:")
print("\nHuman Reviewers - Mean Aspect Scores:")
print(human_means.to_frame('Mean').T)
print("\nAI Reviewers - Mean Aspect Scores:")
print(ai_means.to_frame('Mean').T)
# Out:
# Summary Statistics:
#
# Human Reviewers - Mean Aspect Scores:
#       accuracy  clarity  consistency  novelty  replicability  thoroughness  \
# Mean       3.6      3.0          2.8      3.8            2.0           3.2
#
#       positive  negative
# Mean       3.8       3.4
#
# AI Reviewers - Mean Aspect Scores:
#       accuracy  clarity  consistency  novelty  replicability  thoroughness  \
# Mean       3.8      3.8          2.8      4.4            3.0           3.4
#
#       positive  negative
# Mean       4.0       2.6

# %% [markdown]
# # Exercise #1: Mix Human Reviews with AI Reviews
#
# ### Here, we test: how LLM editors may make decisions based on mixed reviews.
#
# - Configuration for reviewer mixture experiment
# - We will randomly replace X human reviews with AI reviews (1 <= X <= TOTAL_REVIEWS)
# - and measure how this affects the editor's decision

# %% [markdown]
# ## TODO #4: Adjust the number of LLM reviewers in a panel

# %%
TOTAL_REVIEWS = len(HUMAN_REVIEWS)
print("you can only choose between 1 and", TOTAL_REVIEWS, "AI reviews to mix with")

# Number of AI reviews to substitute (from 1 to all reviews)
num_selection = 2 # [EDIT THIS NUMBER HERE]
# NUM_AI_REVIEWS_TO_TEST = list(range(1, TOTAL_REVIEWS + 1))
# Out:
# you can only choose between 1 and 5 AI reviews to mix with

# %%
NUM_AI_REVIEWS_TO_TEST = [num_selection]

# Number of random shuffles/runs per configuration to account for variance
# For each X, we randomly select which X human reviews to replace with AI reviews
NUM_SHUFFLE_RUNS = 3

# Store results for analysis
mixture_results = []

def create_mixed_review_set(human_reviews, ai_reviews, num_ai_to_include, seed=None):
    """
    Create a mixed set of reviews by randomly replacing some human reviews with AI reviews.

    Args:
        human_reviews: List of human review texts
        ai_reviews: List of AI review texts
        num_ai_to_include: Number of human reviews to replace with AI reviews (1 to len(human_reviews))
        seed: Random seed for reproducibility

    Returns:
        mixed_reviews: List of reviews with some human reviews replaced by AI reviews
        replacement_indices: Indices of human reviews that were replaced
    """
    if seed is not None:
        random.seed(seed)

    num_human = len(human_reviews)
    num_ai = len(ai_reviews)

    # Ensure we don't try to replace more reviews than we have
    num_ai_to_include = min(num_ai_to_include, num_human, num_ai)

    # Randomly select which human review positions to replace
    replacement_indices = sorted(random.sample(range(num_human), num_ai_to_include))

    # Randomly select which AI reviews to use
    ai_indices = random.sample(range(num_ai), num_ai_to_include)

    # Create the mixed review set
    mixed_reviews = human_reviews.copy()
    review_sources = ['human'] * num_human  # Track source of each review

    for i, (human_idx, ai_idx) in enumerate(zip(replacement_indices, ai_indices)):
        mixed_reviews[human_idx] = ai_reviews[ai_idx]
        review_sources[human_idx] = 'AI'

    return mixed_reviews, replacement_indices, review_sources

print(f"Total human reviews available: {TOTAL_REVIEWS}")
print(f"AI review counts to test: {NUM_AI_REVIEWS_TO_TEST}")
print(f"Shuffle runs per configuration: {NUM_SHUFFLE_RUNS}")
print(f"Total simulations to run: {len(NUM_AI_REVIEWS_TO_TEST) * NUM_SHUFFLE_RUNS}")
print(f"\nExperiment design:")
print(f"  - For each X in {NUM_AI_REVIEWS_TO_TEST}:")
print(f"    - Randomly select X human reviews to replace with AI reviews")
print(f"    - Repeat {NUM_SHUFFLE_RUNS} times with different random selections")
print(f"    - Measure editor decision for each configuration")


def make_review_blocks_from_texts(
    reviews: Sequence[Union[str, Dict[str, Any]]],
    heading_prefix: str = "Review",
) -> List[Dict[str, str]]:
    """Convert a list of review texts/dicts into heading/body blocks."""
    blocks: List[Dict[str, str]] = []
    for idx, review in enumerate(reviews, start=1):
        if isinstance(review, (dict, str)):
            body = flatten_review_text_ai(review)
        else:
            body = str(review)
        blocks.append({"heading": f"{heading_prefix} {idx}", "body": body})
    return blocks

def render_review_blocks(review_blocks: Sequence[Dict[str, str]]) -> str:
    """Render review blocks into the markdown-like format used by the editor."""
    parts = []
    for block in review_blocks:
        heading = block.get("heading", "Review")
        body = block.get("body", "").strip()
        parts.append(f"{heading}:\n{body}".strip())
    return "\n\n---\n\n".join(parts)

def run_editor_simulation(
    review_blocks: Sequence[Dict[str, str]],
    include_paper_text: bool = True,
    paper_text: Optional[str] = None,
) -> Any:
    """Invoke the editor agent on the provided set of reviews."""
    if not review_blocks:
        raise ValueError("No reviews provided for the editor simulation.")
    editor = make_editor_agent()
    reviews_text = render_review_blocks(review_blocks)
    prompt_sections = []
    if include_paper_text:
        prompt_sections.append(f"Paper:\n{paper_text or PAPER_TEXT}")
    prompt_sections.append(
        "Please make a decision for this paper based on the following reviews:\n\n" + reviews_text
    )
    input_message = "\n\n".join(prompt_sections)
    return editor.generate_reply(messages=[{"role": "user", "content": input_message}])

def summarize_decisions(
    results_df: pd.DataFrame,
    group_key: str,
    decision_col: str = "parsed_decision",
    confidence_col: str = "parsed_confidence",
    score_col: str = "parsed_score",
) -> Tuple[pd.DataFrame, Optional[pd.DataFrame], Optional[pd.DataFrame]]:
    """Return decision counts plus optional confidence/score summaries grouped by `group_key`."""
    if results_df.empty or group_key not in results_df.columns or decision_col not in results_df.columns:
        return pd.DataFrame(), None, None
    decision_counts = (
        results_df.groupby([group_key, decision_col])
        .size()
        .unstack(fill_value=0)
        .sort_index()
    )
    confidence_summary = None
    if confidence_col in results_df.columns:
        confidence_summary = (
            results_df.groupby(group_key)[confidence_col]
            .agg(["mean", "std", "count"])
            .sort_index()
        )
    score_summary = None
    if score_col in results_df.columns:
        score_summary = (
            results_df.groupby(group_key)[score_col]
            .agg(["mean", "std", "count"])
            .sort_index()
        )
    return decision_counts, confidence_summary, score_summary
# Out:
# Total human reviews available: 5
# AI review counts to test: [2]
# Shuffle runs per configuration: 3
# Total simulations to run: 3
#
# Experiment design:
#   - For each X in [2]:
#     - Randomly select X human reviews to replace with AI reviews
#     - Repeat 3 times with different random selections
#     - Measure editor decision for each configuration

# %%
# Store results in a structured format
AI_EDITOR_AI_REVIEWERS_SIMULATION_RESULTS = []

# Calculate total iterations for progress bar
total_iterations = len([1, 2, 3]) * NUM_SHUFFLE_RUNS
ai_review_inputs = AI_REVIEW_TEXTS if AI_REVIEW_TEXTS else [flatten_review_text_ai(review) for review in AI_REVIEWS]

with tqdm(total=total_iterations, desc="Running simulations") as pbar:
    for num_ai_reviews in [1, 2, 3]:
        for run_idx in range(NUM_SHUFFLE_RUNS):
            reviews, replacement_indices, review_sources = create_mixed_review_set(
                HUMAN_REVIEWS,
                ai_review_inputs,
                num_ai_reviews,
            )
            review_blocks = make_review_blocks_from_texts(reviews)
            response = run_editor_simulation(review_blocks, include_paper_text=True, paper_text=PAPER_TEXT)

            # Store the result
            AI_EDITOR_AI_REVIEWERS_SIMULATION_RESULTS.append({
                "num_ai_reviews": num_ai_reviews,
                "run_idx": run_idx,
                "replacement_indices": replacement_indices,
                "review_sources": review_sources,
                "editor_response": response
            })

            pbar.update(1)
# Out:
# Running simulations: 100%|██████████| 9/9 [00:33<00:00,  3.74s/it]

# %%
# Parse decisions from editor responses
def parse_editor_decision(response):
    """
    Parse the decision from the editor's response.
    Handles both JSON format and plain text responses.
    """
    if not response:
        return None

    try:
        # Try to parse as JSON first
        if isinstance(response, str):
            # Look for JSON object in the response
            json_match = re.search(r'\{.*\}', response, re.DOTALL)
            if json_match:
                parsed = json.loads(json_match.group())
                return parsed.get('decision')
        elif isinstance(response, dict):
            return response.get('decision')
    except (json.JSONDecodeError, AttributeError):
        pass

    # Fallback: look for common decision patterns in text
    response_str = str(response).lower()
    if 'accept (poster)' in response_str or 'accept(poster)' in response_str:
        return 'Accept (Poster)'
    elif 'accept (oral)' in response_str or 'accept(oral)' in response_str:
        return 'Accept (Oral)'
    elif 'accept' in response_str:
        return 'Accept'
    elif 'reject' in response_str:
        return 'Reject'

    return None

def parse_editor_confidence(response):
    """Parse the confidence (0-1 float) from the editor response."""
    if not response:
        return None

    try:
        if isinstance(response, str):
            json_match = re.search(r'\{.*\}', response, re.DOTALL)
            if json_match:
                parsed = json.loads(json_match.group())
                confidence = parsed.get('confidence')
                if isinstance(confidence, (int, float)):
                    return float(confidence)
        elif isinstance(response, dict):
            confidence = response.get('confidence')
            if isinstance(confidence, (int, float)):
                return float(confidence)
    except (json.JSONDecodeError, TypeError):
        pass

    response_str = str(response)
    conf_match = re.search(r'confidence[^0-9]*([01](?:\.\d+)?)', response_str, re.IGNORECASE)
    if conf_match:
        try:
            value = float(conf_match.group(1))
            if 0 <= value <= 1:
                return value
        except ValueError:
            pass

    return None

def parse_editor_score(response):
    """Parse the 1-10 paper quality score from the editor response."""
    if not response:
        return None

    try:
        if isinstance(response, str):
            json_match = re.search(r'\{.*\}', response, re.DOTALL)
            if json_match:
                parsed = json.loads(json_match.group())
                score = parsed.get('score')
                if isinstance(score, (int, float)):
                    if 1 <= float(score) <= 10:
                        return float(score)
        elif isinstance(response, dict):
            score = response.get('score')
            if isinstance(score, (int, float)) and 1 <= float(score) <= 10:
                return float(score)
    except (json.JSONDecodeError, TypeError):
        pass

    response_str = str(response)
    score_match = re.search(r'score[^0-9]*((?:10)|(?:[1-9](?:\.\d+)?))', response_str, re.IGNORECASE)
    if score_match:
        try:
            value = float(score_match.group(1))
            if 1 <= value <= 10:
                return value
        except ValueError:
            pass

    return None

# Add parsed decisions to results
for result in AI_EDITOR_AI_REVIEWERS_SIMULATION_RESULTS:
    result['parsed_decision'] = parse_editor_decision(result['editor_response'])
    result['parsed_confidence'] = parse_editor_confidence(result['editor_response'])
    result['parsed_score'] = parse_editor_score(result['editor_response'])

# Display summary
print("Parsed decisions summary:")
for result in AI_EDITOR_AI_REVIEWERS_SIMULATION_RESULTS:
    print(f"Run {result['run_idx']} with {result['num_ai_reviews']} AI reviews: {result['parsed_decision']}")

mixture_results_df = pd.DataFrame(AI_EDITOR_AI_REVIEWERS_SIMULATION_RESULTS)
if not mixture_results_df.empty:
    decision_summary, confidence_summary, score_summary = summarize_decisions(
        mixture_results_df,
        group_key="num_ai_reviews",
    )
    if not decision_summary.empty:
        print("Editor decision counts by number of AI reviews:")
        display(decision_summary)
    if confidence_summary is not None and not confidence_summary.empty:
        print("Editor confidence by number of AI reviews:")
        display(confidence_summary)
        conf_plot = confidence_summary.copy().reset_index()
        conf_plot["sem"] = conf_plot["std"] / np.sqrt(conf_plot["count"].replace(0, np.nan))
        fig, ax = plt.subplots(figsize=(6, 4))
        ax.errorbar(
            conf_plot["num_ai_reviews"],
            conf_plot["mean"],
            yerr=conf_plot["sem"].fillna(0),
            fmt="-o",
            color="#1f77b4",
            capsize=4,
        )
        ax.set_xlabel("Number of AI reviews in mix")
        ax.set_ylabel("Editor confidence (0-1)")
        ax.set_ylim(0, 1)
        ax.set_title("Confidence vs. AI review count")
        ax.grid(alpha=0.3)
        plt.tight_layout()
        plt.show()
    if score_summary is not None and not score_summary.empty:
        print("Editor quality score by number of AI reviews:")
        display(score_summary)
        score_plot = score_summary.copy().reset_index()
        score_plot["sem"] = score_plot["std"] / np.sqrt(score_plot["count"].replace(0, np.nan))
        fig, ax = plt.subplots(figsize=(6, 4))
        ax.errorbar(
            score_plot["num_ai_reviews"],
            score_plot["mean"],
            yerr=score_plot["sem"].fillna(0),
            fmt="-o",
            color="#d62728",
            capsize=4,
        )
        ax.set_xlabel("Number of AI reviews in mix")
        ax.set_ylabel("Editor quality score (1-10)")
        ax.set_ylim(1, 10)
        ax.set_title("Quality score vs. AI review count")
        ax.grid(alpha=0.3)
        plt.tight_layout()
        plt.show()
else:
    print("No editor simulations recorded; run the previous cell first.")
# Out:
# Parsed decisions summary:
# Run 0 with 1 AI reviews: Reject
# Run 1 with 1 AI reviews: Accept (Poster)
# Run 2 with 1 AI reviews: Reject
# Run 0 with 2 AI reviews: Accept (Poster)
# Run 1 with 2 AI reviews: Accept (Poster)
# Run 2 with 2 AI reviews: Accept (Poster)
# Run 0 with 3 AI reviews: Accept (Poster)
# Run 1 with 3 AI reviews: Accept (Poster)
# Run 2 with 3 AI reviews: Accept (Spotlight)
# Editor decision counts by number of AI reviews:
# parsed_decision  Accept (Poster)  Accept (Spotlight)  Reject
# num_ai_reviews
# 1                              1                   0       2
# 2                              3                   0       0
# 3                              2                   1       0
# Editor confidence by number of AI reviews:
#                     mean       std  count
# num_ai_reviews
# 1               0.766667  0.028868      3
# 2               0.816667  0.028868      3
# 3               0.816667  0.057735      3
# Editor quality score by number of AI reviews:
#                     mean      std  count
# num_ai_reviews
# 1               6.000000  1.00000      3
# 2               7.333333  0.57735      3
# 3               8.000000  1.00000      3

# %%
ACTUAL_DECISION
# Out:
# 'Accept (Poster)'

# %% [markdown]
# # Exercise #2: Mix LLM Reviewers from Different Domains
#
# ### Here, we test: how LLM editors make decisions based on reviews written by LLM reviewer agents from different domain
#
# Note: because we don't know the identity of real human reviewers, we cannot easily control for the domain and seniority of human reviewers. We will generate AI reviewers from different domains and seniorities.

# %% [markdown]
# ### While you don't need to edit anything, the paper of your choice (in TODO #2) is the domain that a LLM reviewer agent will be assigned to.
#
# This will test: whether we involve 1 domain expertise of your paper will influence the peer review process.

# %%
# Build a balanced panel of 10 AI reviewers (all junior faculty)
NUM_SAME_DOMAIN_JUNIOR = 5
NUM_RANDOM_DOMAIN_JUNIOR = 5

MIXED_DOMAIN_AI_PANEL_STATE = (
    [{"domain": "same", "seniority": "Junior faculty"} for _ in range(NUM_SAME_DOMAIN_JUNIOR)]
    + [{"domain": "Machine Learning", "seniority": "Junior faculty"} for _ in range(NUM_RANDOM_DOMAIN_JUNIOR)]
)

mixed_domain_personas = create_reviewer_personas_from_state(
    MIXED_DOMAIN_AI_PANEL_STATE,
    paper_domain=PAPER_DOMAIN,
)

MIXED_DOMAIN_AI_REVIEWERS = [make_reviewer_agent(persona) for persona in mixed_domain_personas]

# Reuse global reviewer references so downstream cells operate on this configuration
AI_PANEL_STATE = MIXED_DOMAIN_AI_PANEL_STATE
personas = mixed_domain_personas
AI_REVIEWERS = MIXED_DOMAIN_AI_REVIEWERS

mixed_domain_summary = pd.DataFrame(
    [
        {
            "name": persona.name,
            "expertise": persona.expertise,
            "seniority": persona.seniority,
            "domain_source": "same" if persona.expertise == PAPER_DOMAIN else "random_different",
        }
        for persona in mixed_domain_personas
    ]
)

print("AI reviewer panel: 5 same-domain + 5 random-different (all junior faculty)")
display(mixed_domain_summary)
print(mixed_domain_summary["domain_source"].value_counts())
# Out:
# AI reviewer panel: 5 same-domain + 5 random-different (all junior faculty)
#                                                 name         expertise  \
# 0         AI Reviewer_1: Junior faculty in Causality         Causality
# 1         AI Reviewer_2: Junior faculty in Causality         Causality
# 2         AI Reviewer_3: Junior faculty in Causality         Causality
# 3         AI Reviewer_4: Junior faculty in Causality         Causality
# 4         AI Reviewer_5: Junior faculty in Causality         Causality
# 5  AI Reviewer_6: Junior faculty in Machine Learning  Machine Learning
# 6  AI Reviewer_7: Junior faculty in Machine Learning  Machine Learning
# 7  AI Reviewer_8: Junior faculty in Machine Learning  Machine Learning
# 8  AI Reviewer_9: Junior faculty in Machine Learning  Machine Learning
# 9  AI Reviewer_10: Junior faculty in Machine Lear...  Machine Learning
#
#         seniority     domain_source
# 0  Junior faculty              same
# 1  Junior faculty              same
# 2  Junior faculty              same
# 3  Junior faculty              same
# 4  Junior faculty              same
# 5  Junior faculty  random_different
# 6  Junior faculty  random_different
# 7  Junior faculty  random_different
# 8  Junior faculty  random_different
# 9  Junior faculty  random_different
# domain_source
# same                5
# random_different    5
# Name: count, dtype: int64

# %% [markdown]
# ### Now we experiment how the involvement of outsider reviewers (i.e., reviewers from different domains) affects the editor's decision.
# We fix the panel size to five AI reviews per editor call and vary how many of those five come from the default domain of the machine learning (0-5 machine learning experts). Each configuration is sampled multiple times to average out randomness in the reviewer pool and the editor's LLM responses.

# %%
print("Regenerating AI reviews for the mixed-domain personas …")
generate_ai_reviews()
# Out:
# Regenerating AI reviews for the mixed-domain personas …
# Generating 10 AI reviews …
# ✓ AI Reviewer_1: Junior faculty in Causality
# ✓ AI Reviewer_2: Junior faculty in Causality
# ✓ AI Reviewer_3: Junior faculty in Causality
# ✓ AI Reviewer_4: Junior faculty in Causality
# ✓ AI Reviewer_5: Junior faculty in Causality
# ✓ AI Reviewer_6: Junior faculty in Machine Learning
# ✓ AI Reviewer_7: Junior faculty in Machine Learning
# ✓ AI Reviewer_8: Junior faculty in Machine Learning
# ✓ AI Reviewer_9: Junior faculty in Machine Learning
# ✓ AI Reviewer_10: Junior faculty in Machine Learning
# Completed in 0.1s. Generated 10 reviews.
#
# --- AI Reviewer_1: Junior faculty in Causality ---
# ```json
# {
#   "persona": {
#     "expertise": "Causality",
#     "seniority": "Junior faculty"
#   },
#   "review": {
#     "summary": [
#       "The paper presents a large-scale benchmark study evaluating conditional average treatment effect (CATE) estimation algorithms. It finds that many current CATE models perform poorly in capturing real-world heterogeneity, with a significant proportion yielding negligible results compared to trivial estimators.",
#       "The authors introduce a novel evaluation metric, Q, which helps assess CATE models in practical scenarios without the need for counterfactual outcomes."
#     ],
#     "strengths": [
#       "The research addresses a critical topic in causal inference and provides empirical evidence that raises important questions about the efficacy of existing CATE models.",
#       "The novel approach of observational sampling combined with the proposed Q statistic provides a significant contribution to the methodology for CATE evaluation.",
#       "The benchmark's reliance on real-world datasets enhances the validity of the findings compared to previous studies predominantly using simulated outcomes.",
#       "The large scale of the study (16 models on 12 datasets with 43,200 sampled variants) contributes to the robustness of the results."
#     ],
#     "weaknesses": [
#       "The threshold of model effectiveness is primarily determined by comparison against trivial and constant-effect estimators, which may not fully capture the nuances of practical applications in various fields.",
#       "The findings indicate a systemic issue in model performance, but further investigation is needed on why these weaknesses exist and what practical steps can be taken to improve performance.",
#       "The paper could benefit from additional discussion on the implications of the findings for practitioners and future research directions."
#     ],
#     "questions": [
#       "How do the authors suggest practitioners should adapt their choice of CATE models in light of the findings?",
#       "Could the authors provide a more detailed analysis of how the proposed metric Q compares to existing evaluation methods in terms of areas such as variance and bias?",
#       "What are the implications of the findings for ongoing and future work in the CATE estimation landscape?"
#     ],
#     "rating": 8,
#     "confidence": 4
#   }
# }
# ```
#
# --- AI Reviewer_2: Junior faculty in Causality ---
# ```json
# {
#   "persona": {
#     "expertise": "Causality",
#     "seniority": "Junior faculty"
#   },
#   "review": {
#     "summary": [
#       "The paper presents a large-scale benchmark study evaluating conditional average treatment effect (CATE) estimation algorithms. It finds that many current CATE models perform poorly in capturing real-world heterogeneity, with a significant proportion yielding negligible results compared to trivial estimators.",
#       "The authors introduce a novel evaluation metric, Q, which helps assess CATE models in practical scenarios without the need for counterfactual outcomes."
#     ],
#     "strengths": [
#       "The research addresses a critical topic in causal inference and provides empirical evidence that raises important questions about the efficacy of existing CATE models.",
#       "The novel approach of observational sampling combined with the proposed Q statistic provides a significant contribution to the methodology for CATE evaluation.",
#       "The benchmark's reliance on real-world datasets enhances the validity of the findings compared to previous studies predominantly using simulated outcomes.",
#       "The large scale of the study (16 models on 12 datasets with 43,200 sampled variants) contributes to the robustness of the results."
#     ],
#     "weaknesses": [
#       "The threshold of model effectiveness is primarily determined by comparison against trivial and constant-effect estimators, which may not fully capture the nuances of practical applications in various fields.",
#       "The findings indicate a systemic issue in model performance, but further investigation is needed on why these weaknesses exist and what practical steps can be taken to improve performance.",
#       "The paper could benefit from additional discussion on the implications of the findings for practitioners and future research directions."
#     ],
#     "questions": [
#       "How do the authors suggest practitioners should adapt their choice of CATE models in light of the findings?",
#       "Could the authors provide a more detailed analysis of how the proposed metric Q compares to existing evaluation methods in terms of areas such as variance and bias?",
#       "What are the implications of the findings for ongoing and future work in the CATE estimation landscape?"
#     ],
#     "rating": 8,
#     "confidence": 4
#   }
# }
# ```
#
# --- AI Reviewer_3: Junior faculty in Causality ---
# ```json
# {
#   "persona": {
#     "expertise": "Causality",
#     "seniority": "Junior faculty"
#   },
#   "review": {
#     "summary": [
#       "The paper presents a large-scale benchmark study evaluating conditional average treatment effect (CATE) estimation algorithms. It finds that many current CATE models perform poorly in capturing real-world heterogeneity, with a significant proportion yielding negligible results compared to trivial estimators.",
#       "The authors introduce a novel evaluation metric, Q, which helps assess CATE models in practical scenarios without the need for counterfactual outcomes."
#     ],
#     "strengths": [
#       "The research addresses a critical topic in causal inference and provides empirical evidence that raises important questions about the efficacy of existing CATE models.",
#       "The novel approach of observational sampling combined with the proposed Q statistic provides a significant contribution to the methodology for CATE evaluation.",
#       "The benchmark's reliance on real-world datasets enhances the validity of the findings compared to previous studies predominantly using simulated outcomes.",
#       "The large scale of the study (16 models on 12 datasets with 43,200 sampled variants) contributes to the robustness of the results."
#     ],
#     "weaknesses": [
#       "The threshold of model effectiveness is primarily determined by comparison against trivial and constant-effect estimators, which may not fully capture the nuances of practical applications in various fields.",
#       "The findings indicate a systemic issue in model performance, but further investigation is needed on why these weaknesses exist and what practical steps can be taken to improve performance.",
#       "The paper could benefit from additional discussion on the implications of the findings for practitioners and future research directions."
#     ],
#     "questions": [
#       "How do the authors suggest practitioners should adapt their choice of CATE models in light of the findings?",
#       "Could the authors provide a more detailed analysis of how the proposed metric Q compares to existing evaluation methods in terms of areas such as variance and bias?",
#       "What are the implications of the findings for ongoing and future work in the CATE estimation landscape?"
#     ],
#     "rating": 8,
#     "confidence": 4
#   }
# }
# ```
#
# --- AI Reviewer_4: Junior faculty in Causality ---
# ```json
# {
#   "persona": {
#     "expertise": "Causality",
#     "seniority": "Junior faculty"
#   },
#   "review": {
#     "summary": [
#       "The paper presents a large-scale benchmark study evaluating conditional average treatment effect (CATE) estimation algorithms. It finds that many current CATE models perform poorly in capturing real-world heterogeneity, with a significant proportion yielding negligible results compared to trivial estimators.",
#       "The authors introduce a novel evaluation metric, Q, which helps assess CATE models in practical scenarios without the need for counterfactual outcomes."
#     ],
#     "strengths": [
#       "The research addresses a critical topic in causal inference and provides empirical evidence that raises important questions about the efficacy of existing CATE models.",
#       "The novel approach of observational sampling combined with the proposed Q statistic provides a significant contribution to the methodology for CATE evaluation.",
#       "The benchmark's reliance on real-world datasets enhances the validity of the findings compared to previous studies predominantly using simulated outcomes.",
#       "The large scale of the study (16 models on 12 datasets with 43,200 sampled variants) contributes to the robustness of the results."
#     ],
#     "weaknesses": [
#       "The threshold of model effectiveness is primarily determined by comparison against trivial and constant-effect estimators, which may not fully capture the nuances of practical applications in various fields.",
#       "The findings indicate a systemic issue in model performance, but further investigation is needed on why these weaknesses exist and what practical steps can be taken to improve performance.",
#       "The paper could benefit from additional discussion on the implications of the findings for practitioners and future research directions."
#     ],
#     "questions": [
#       "How do the authors suggest practitioners should adapt their choice of CATE models in light of the findings?",
#       "Could the authors provide a more detailed analysis of how the proposed metric Q compares to existing evaluation methods in terms of areas such as variance and bias?",
#       "What are the implications of the findings for ongoing and future work in the CATE estimation landscape?"
#     ],
#     "rating": 8,
#     "confidence": 4
#   }
# }
# ```
#
# --- AI Reviewer_5: Junior faculty in Causality ---
# ```json
# {
#   "persona": {
#     "expertise": "Causality",
#     "seniority": "Junior faculty"
#   },
#   "review": {
#     "summary": [
#       "The paper presents a large-scale benchmark study evaluating conditional average treatment effect (CATE) estimation algorithms. It finds that many current CATE models perform poorly in capturing real-world heterogeneity, with a significant proportion yielding negligible results compared to trivial estimators.",
#       "The authors introduce a novel evaluation metric, Q, which helps assess CATE models in practical scenarios without the need for counterfactual outcomes."
#     ],
#     "strengths": [
#       "The research addresses a critical topic in causal inference and provides empirical evidence that raises important questions about the efficacy of existing CATE models.",
#       "The novel approach of observational sampling combined with the proposed Q statistic provides a significant contribution to the methodology for CATE evaluation.",
#       "The benchmark's reliance on real-world datasets enhances the validity of the findings compared to previous studies predominantly using simulated outcomes.",
#       "The large scale of the study (16 models on 12 datasets with 43,200 sampled variants) contributes to the robustness of the results."
#     ],
#     "weaknesses": [
#       "The threshold of model effectiveness is primarily determined by comparison against trivial and constant-effect estimators, which may not fully capture the nuances of practical applications in various fields.",
#       "The findings indicate a systemic issue in model performance, but further investigation is needed on why these weaknesses exist and what practical steps can be taken to improve performance.",
#       "The paper could benefit from additional discussion on the implications of the findings for practitioners and future research directions."
#     ],
#     "questions": [
#       "How do the authors suggest practitioners should adapt their choice of CATE models in light of the findings?",
#       "Could the authors provide a more detailed analysis of how the proposed metric Q compares to existing evaluation methods in terms of areas such as variance and bias?",
#       "What are the implications of the findings for ongoing and future work in the CATE estimation landscape?"
#     ],
#     "rating": 8,
#     "confidence": 4
#   }
# }
# ```
#
# --- AI Reviewer_6: Junior faculty in Machine Learning ---
# {
#   "persona": {
#     "expertise": "Machine Learning",
#     "seniority": "Junior faculty"
#   },
#   "review": {
#     "summary": [
#       "The paper presents a comprehensive benchmark study assessing Conditional Average Treatment Effect (CATE) estimation algorithms through a novel approach that incorporates observational sampling and a newly defined statistical parameter, Q. The authors highlight significant shortcomings in contemporary CATE models, demonstrating that many of them fail to outperform trivial benchmarks. This paper sheds light on the challenges of evaluating these models in practice, particularly in capturing real-world heterogeneity."
#     ],
#     "strengths": [
#       "The study is well-structured and clearly articulates the motivation behind assessing CATE models using real-world data rather than simulations.",
#       "The use of 43,200 sampled variants from 12 datasets ensures a robust empirical foundation for the claims made.",
#       "The introduction of the statistical parameter Q is innovative and provides a new perspective on evaluating CATE estimators, addressing gaps in existing evaluation methods.",
#       "The findings challenge established beliefs in the effectiveness of certain model types, which is crucial for future research directions.",
#       "The paper acknowledges potential limitations and discusses necessary steps for generalizability, showcasing thoughtfully conducted research."
#     ],
#     "weaknesses": [
#       "While the paper asserts significant findings, some additional analysis on the underlying reasons for the observed inefficacy of certain models would enhance the depth of the study.",
#       "The reliance on specific datasets may limit the generalizability of the findings; the authors should consider broader datasets in future work.",
#       "Though the metrics and methodologies are rigorously presented, certain technical aspects, such as sample selection bias, might require clearer explanations for readers less familiar with causal inference."
#     ],
#     "questions": [
#       "Could the authors elaborate on the limitations they foresee regarding observational sampling in different contexts or domains?",
#       "What strategies do the authors suggest for practitioners to mitigate the risks associated with using CATE models based on their findings?",
#       "Can the authors offer insights into how the Q statistic may hold up under different data distributions or settings?",
#       "What are the specific characteristics of datasets where CATE models tend to perform better, based on their analyses?"
#     ],
#     "rating": 8,
#     "confidence": 4
#   }
# }
#
# --- AI Reviewer_7: Junior faculty in Machine Learning ---
# {
#   "persona": {
#     "expertise": "Machine Learning",
#     "seniority": "Junior faculty"
#   },
#   "review": {
#     "summary": [
#       "The paper presents a comprehensive benchmark study assessing Conditional Average Treatment Effect (CATE) estimation algorithms through a novel approach that incorporates observational sampling and a newly defined statistical parameter, Q. The authors highlight significant shortcomings in contemporary CATE models, demonstrating that many of them fail to outperform trivial benchmarks. This paper sheds light on the challenges of evaluating these models in practice, particularly in capturing real-world heterogeneity."
#     ],
#     "strengths": [
#       "The study is well-structured and clearly articulates the motivation behind assessing CATE models using real-world data rather than simulations.",
#       "The use of 43,200 sampled variants from 12 datasets ensures a robust empirical foundation for the claims made.",
#       "The introduction of the statistical parameter Q is innovative and provides a new perspective on evaluating CATE estimators, addressing gaps in existing evaluation methods.",
#       "The findings challenge established beliefs in the effectiveness of certain model types, which is crucial for future research directions.",
#       "The paper acknowledges potential limitations and discusses necessary steps for generalizability, showcasing thoughtfully conducted research."
#     ],
#     "weaknesses": [
#       "While the paper asserts significant findings, some additional analysis on the underlying reasons for the observed inefficacy of certain models would enhance the depth of the study.",
#       "The reliance on specific datasets may limit the generalizability of the findings; the authors should consider broader datasets in future work.",
#       "Though the metrics and methodologies are rigorously presented, certain technical aspects, such as sample selection bias, might require clearer explanations for readers less familiar with causal inference."
#     ],
#     "questions": [
#       "Could the authors elaborate on the limitations they foresee regarding observational sampling in different contexts or domains?",
#       "What strategies do the authors suggest for practitioners to mitigate the risks associated with using CATE models based on their findings?",
#       "Can the authors offer insights into how the Q statistic may hold up under different data distributions or settings?",
#       "What are the specific characteristics of datasets where CATE models tend to perform better, based on their analyses?"
#     ],
#     "rating": 8,
#     "confidence": 4
#   }
# }
#
# --- AI Reviewer_8: Junior faculty in Machine Learning ---
# {
#   "persona": {
#     "expertise": "Machine Learning",
#     "seniority": "Junior faculty"
#   },
#   "review": {
#     "summary": [
#       "The paper presents a comprehensive benchmark study assessing Conditional Average Treatment Effect (CATE) estimation algorithms through a novel approach that incorporates observational sampling and a newly defined statistical parameter, Q. The authors highlight significant shortcomings in contemporary CATE models, demonstrating that many of them fail to outperform trivial benchmarks. This paper sheds light on the challenges of evaluating these models in practice, particularly in capturing real-world heterogeneity."
#     ],
#     "strengths": [
#       "The study is well-structured and clearly articulates the motivation behind assessing CATE models using real-world data rather than simulations.",
#       "The use of 43,200 sampled variants from 12 datasets ensures a robust empirical foundation for the claims made.",
#       "The introduction of the statistical parameter Q is innovative and provides a new perspective on evaluating CATE estimators, addressing gaps in existing evaluation methods.",
#       "The findings challenge established beliefs in the effectiveness of certain model types, which is crucial for future research directions.",
#       "The paper acknowledges potential limitations and discusses necessary steps for generalizability, showcasing thoughtfully conducted research."
#     ],
#     "weaknesses": [
#       "While the paper asserts significant findings, some additional analysis on the underlying reasons for the observed inefficacy of certain models would enhance the depth of the study.",
#       "The reliance on specific datasets may limit the generalizability of the findings; the authors should consider broader datasets in future work.",
#       "Though the metrics and methodologies are rigorously presented, certain technical aspects, such as sample selection bias, might require clearer explanations for readers less familiar with causal inference."
#     ],
#     "questions": [
#       "Could the authors elaborate on the limitations they foresee regarding observational sampling in different contexts or domains?",
#       "What strategies do the authors suggest for practitioners to mitigate the risks associated with using CATE models based on their findings?",
#       "Can the authors offer insights into how the Q statistic may hold up under different data distributions or settings?",
#       "What are the specific characteristics of datasets where CATE models tend to perform better, based on their analyses?"
#     ],
#     "rating": 8,
#     "confidence": 4
#   }
# }
#
# --- AI Reviewer_9: Junior faculty in Machine Learning ---
# {
#   "persona": {
#     "expertise": "Machine Learning",
#     "seniority": "Junior faculty"
#   },
#   "review": {
#     "summary": [
#       "The paper presents a comprehensive benchmark study assessing Conditional Average Treatment Effect (CATE) estimation algorithms through a novel approach that incorporates observational sampling and a newly defined statistical parameter, Q. The authors highlight significant shortcomings in contemporary CATE models, demonstrating that many of them fail to outperform trivial benchmarks. This paper sheds light on the challenges of evaluating these models in practice, particularly in capturing real-world heterogeneity."
#     ],
#     "strengths": [
#       "The study is well-structured and clearly articulates the motivation behind assessing CATE models using real-world data rather than simulations.",
#       "The use of 43,200 sampled variants from 12 datasets ensures a robust empirical foundation for the claims made.",
#       "The introduction of the statistical parameter Q is innovative and provides a new perspective on evaluating CATE estimators, addressing gaps in existing evaluation methods.",
#       "The findings challenge established beliefs in the effectiveness of certain model types, which is crucial for future research directions.",
#       "The paper acknowledges potential limitations and discusses necessary steps for generalizability, showcasing thoughtfully conducted research."
#     ],
#     "weaknesses": [
#       "While the paper asserts significant findings, some additional analysis on the underlying reasons for the observed inefficacy of certain models would enhance the depth of the study.",
#       "The reliance on specific datasets may limit the generalizability of the findings; the authors should consider broader datasets in future work.",
#       "Though the metrics and methodologies are rigorously presented, certain technical aspects, such as sample selection bias, might require clearer explanations for readers less familiar with causal inference."
#     ],
#     "questions": [
#       "Could the authors elaborate on the limitations they foresee regarding observational sampling in different contexts or domains?",
#       "What strategies do the authors suggest for practitioners to mitigate the risks associated with using CATE models based on their findings?",
#       "Can the authors offer insights into how the Q statistic may hold up under different data distributions or settings?",
#       "What are the specific characteristics of datasets where CATE models tend to perform better, based on their analyses?"
#     ],
#     "rating": 8,
#     "confidence": 4
#   }
# }
#
# --- AI Reviewer_10: Junior faculty in Machine Learning ---
# {
#   "persona": {
#     "expertise": "Machine Learning",
#     "seniority": "Junior faculty"
#   },
#   "review": {
#     "summary": [
#       "The paper presents a comprehensive benchmark study assessing Conditional Average Treatment Effect (CATE) estimation algorithms through a novel approach that incorporates observational sampling and a newly defined statistical parameter, Q. The authors highlight significant shortcomings in contemporary CATE models, demonstrating that many of them fail to outperform trivial benchmarks. This paper sheds light on the challenges of evaluating these models in practice, particularly in capturing real-world heterogeneity."
#     ],
#     "strengths": [
#       "The study is well-structured and clearly articulates the motivation behind assessing CATE models using real-world data rather than simulations.",
#       "The use of 43,200 sampled variants from 12 datasets ensures a robust empirical foundation for the claims made.",
#       "The introduction of the statistical parameter Q is innovative and provides a new perspective on evaluating CATE estimators, addressing gaps in existing evaluation methods.",
#       "The findings challenge established beliefs in the effectiveness of certain model types, which is crucial for future research directions.",
#       "The paper acknowledges potential limitations and discusses necessary steps for generalizability, showcasing thoughtfully conducted research."
#     ],
#     "weaknesses": [
#       "While the paper asserts significant findings, some additional analysis on the underlying reasons for the observed inefficacy of certain models would enhance the depth of the study.",
#       "The reliance on specific datasets may limit the generalizability of the findings; the authors should consider broader datasets in future work.",
#       "Though the metrics and methodologies are rigorously presented, certain technical aspects, such as sample selection bias, might require clearer explanations for readers less familiar with causal inference."
#     ],
#     "questions": [
#       "Could the authors elaborate on the limitations they foresee regarding observational sampling in different contexts or domains?",
#       "What strategies do the authors suggest for practitioners to mitigate the risks associated with using CATE models based on their findings?",
#       "Can the authors offer insights into how the Q statistic may hold up under different data distributions or settings?",
#       "What are the specific characteristics of datasets where CATE models tend to perform better, based on their analyses?"
#     ],
#     "rating": 8,
#     "confidence": 4
#   }
# }

# %% [markdown]
# ### Explore #2.1: Different aspects of reviews: are in-domain and outsider reviews focusing on the same aspects while writing their reviews?

# %%
# Compare aspect focus for in-domain vs outsider AI reviews and humans
if not AI_REVIEWS:
    raise RuntimeError("Run the AI review generation cell before analyzing aspects.")
if "ASPECT_SCORES_DF" not in globals() or ASPECT_SCORES_DF.empty:
    raise RuntimeError("ASPECT_SCORES_DF is empty; run the earlier scoring cells first.")

persona_lookup = build_persona_lookup(personas)
tagged_reviews = tag_ai_reviews(AI_REVIEWS, persona_lookup, PAPER_DOMAIN)
review_records_for_scoring: List[Dict[str, Any]] = [
    {"persona": tagged["persona"], "response": tagged["response"]}
    for tagged in tagged_reviews
]
domain_labels: Dict[str, str] = {
    tagged["reviewer"]: tagged["domain_source"] for tagged in tagged_reviews
}

if not review_records_for_scoring:
    raise RuntimeError("No review records available for aspect analysis.")

scored_domain_records = score_ai_review_records(review_records_for_scoring, source_label="AI")
scored_domain_df = pd.DataFrame(scored_domain_records)
if scored_domain_df.empty:
    raise RuntimeError("Aspect scoring returned an empty result; rerun the reviews cell.")

scored_domain_df["domain_source"] = scored_domain_df["reviewer"].map(domain_labels).fillna("unknown")
scored_domain_df = scored_domain_df[scored_domain_df["domain_source"].isin(["same", "random_different"])]
if scored_domain_df.empty:
    raise RuntimeError("No reviews classified as same-domain or outsider; regenerate AI reviews.")

human_scores_df = ASPECT_SCORES_DF[ASPECT_SCORES_DF["source"].str.lower() == "human"].copy()
if human_scores_df.empty:
    raise RuntimeError("Human review aspect scores are missing; load and score human reviews first.")
if "reviewer" not in human_scores_df.columns:
    if "name" in human_scores_df.columns:
        human_scores_df["reviewer"] = human_scores_df["name"]
    else:
        human_scores_df["reviewer"] = [f"human_{i+1}" for i in range(len(human_scores_df))]
human_scores_df["domain_source"] = "human"

columns_needed = ["reviewer", "domain_source"] + ASPECT_COLUMNS
ai_subset = scored_domain_df[columns_needed].copy()
human_subset = human_scores_df.reindex(columns=columns_needed)
comparison_df = pd.concat([ai_subset, human_subset], ignore_index=True)

aspects_by_domain = comparison_df.groupby("domain_source")[ASPECT_COLUMNS].mean()
aspect_sem = comparison_df.groupby("domain_source")[ASPECT_COLUMNS].sem().fillna(0)
order = [label for label in ["same", "random_different", "human"] if label in aspects_by_domain.index]
aspects_by_domain = aspects_by_domain.reindex(order)
aspect_sem = aspect_sem.reindex(order).fillna(0)

label_map = {
    "same": "In-domain AI",
    "random_different": "Outsider AI",
    "human": "Human reviewers",
}

print("Average aspect scores by reviewer group:")
display(aspects_by_domain.rename(index=label_map))
print("Standard error of the mean per aspect:")
display(aspect_sem.rename(index=label_map))

x = np.arange(len(ASPECT_COLUMNS))
bar_width = 0.25
fig, ax = plt.subplots(figsize=(11, 5))

for idx, group_key in enumerate(order):
    offset = (idx - (len(order) - 1) / 2) * bar_width
    ax.bar(
        x + offset,
        aspects_by_domain.loc[group_key].values,
        bar_width,
        label=label_map[group_key],
        yerr=aspect_sem.loc[group_key].values,
        capsize=4,
    )

ax.set_xticks(x)
ax.set_xticklabels([col.title() for col in ASPECT_COLUMNS], rotation=30, ha="right")
ax.set_ylabel("Average aspect score (1-5)")
ax.set_title("Aspect emphasis by reviewer group (mean ± s.e.m.)")
# ax.set_ylim(0, 5)
ax.legend()
plt.tight_layout()
plt.show()
# Out:
# Average aspect scores by reviewer group:
#                  accuracy  clarity  consistency  novelty  replicability  \
# domain_source
# In-domain AI          3.8      3.2          3.2      4.4            2.8
# Outsider AI           3.4      4.0          3.0      4.4            2.4
# Human reviewers       3.6      3.0          2.8      3.8            2.0
#
#                  thoroughness  positive  negative
# domain_source
# In-domain AI              3.2       4.0       3.0
# Outsider AI               3.0       4.0       2.4
# Human reviewers           3.2       3.8       3.4
# Standard error of the mean per aspect:
#                  accuracy  clarity  consistency   novelty  replicability  \
# domain_source
# In-domain AI     0.200000      0.2          0.2  0.244949       0.200000
# Outsider AI      0.244949      0.0          0.0  0.244949       0.244949
# Human reviewers  0.244949      0.0          0.2  0.489898       0.316228
#
#                  thoroughness  positive  negative
# domain_source
# In-domain AI         0.200000       0.0  0.000000
# Outsider AI          0.000000       0.0  0.244949
# Human reviewers      0.374166       0.2  0.244949

# %%
print("Sample of scored reviews with group labels:")
display(comparison_df[["reviewer"] + ASPECT_COLUMNS].head(10))
# Out:
# Sample of scored reviews with group labels:
#                                             reviewer  accuracy  clarity  \
# 0         AI Reviewer_1: Junior faculty in Causality       4.0      4.0
# 1         AI Reviewer_2: Junior faculty in Causality       4.0      3.0
# 2         AI Reviewer_3: Junior faculty in Causality       3.0      3.0
# 3         AI Reviewer_4: Junior faculty in Causality       4.0      3.0
# 4         AI Reviewer_5: Junior faculty in Causality       4.0      3.0
# 5  AI Reviewer_6: Junior faculty in Machine Learning       3.0      4.0
# 6  AI Reviewer_7: Junior faculty in Machine Learning       3.0      4.0
# 7  AI Reviewer_8: Junior faculty in Machine Learning       4.0      4.0
# 8  AI Reviewer_9: Junior faculty in Machine Learning       3.0      4.0
# 9  AI Reviewer_10: Junior faculty in Machine Lear...       4.0      4.0
#
#    consistency  novelty  replicability  thoroughness  positive  negative
# 0          3.0      5.0            3.0           3.0       4.0       3.0
# 1          4.0      5.0            3.0           3.0       4.0       3.0
# 2          3.0      4.0            2.0           3.0       4.0       3.0
# 3          3.0      4.0            3.0           3.0       4.0       3.0
# 4          3.0      4.0            3.0           4.0       4.0       3.0
# 5          3.0      4.0            2.0           3.0       4.0       3.0
# 6          3.0      4.0            2.0           3.0       4.0       2.0
# 7          3.0      5.0            2.0           3.0       4.0       3.0
# 8          3.0      4.0            3.0           3.0       4.0       2.0
# 9          3.0      5.0            3.0           3.0       4.0       2.0

# %% [markdown]
# ### Explore #2.2: How does the number of outsider reviews affect the editor's decision?

# %%
OUTSIDER_PANEL_SIZE = min(5, len(AI_REVIEWS))
OUTSIDER_RUNS_PER_SETTING = 3

if OUTSIDER_PANEL_SIZE == 0:
    raise RuntimeError("Generate AI reviews for the mixed-domain panel before running this cell.")

persona_lookup = build_persona_lookup(personas)
tagged_reviews = tag_ai_reviews(AI_REVIEWS, persona_lookup, PAPER_DOMAIN)
review_records: List[Dict[str, Any]] = [
    {
        "reviewer": tagged["reviewer"],
        "domain_source": tagged["domain_source"],
        "text": tagged["text"],
    }
    for tagged in tagged_reviews
    if tagged.get("text")
]

if not review_records:
    raise RuntimeError("AI_REVIEWS is empty after filtering; rerun generate_ai_reviews().")

same_domain_records = [r for r in review_records if r["domain_source"] == "same"]
outsider_records = [r for r in review_records if r["domain_source"] != "same"]

if not same_domain_records or not outsider_records:
    raise RuntimeError("Need both same-domain and outsider reviews to run this experiment.")

if len(same_domain_records) < OUTSIDER_PANEL_SIZE:
    raise RuntimeError(
        f"Not enough same-domain reviews ({len(same_domain_records)}) to fill a panel of {OUTSIDER_PANEL_SIZE} reviewers."
    )

max_outsiders_allowed = min(len(outsider_records), OUTSIDER_PANEL_SIZE)
outsider_counts = list(range(0, max_outsiders_allowed + 1))

OUTSIDER_EXPERIMENT_CONFIG = {
    "panel_size": OUTSIDER_PANEL_SIZE,
    "runs_per_setting": OUTSIDER_RUNS_PER_SETTING,
    "outsider_counts": outsider_counts,
}

OUTSIDER_EDITOR_EXPERIMENT_RESULTS: List[Dict[str, Any]] = []
total_runs = len(outsider_counts) * OUTSIDER_RUNS_PER_SETTING

with tqdm(total=total_runs, desc="Outsider reviewer simulations") as pbar:
    for num_outsiders in outsider_counts:
        num_same_needed = OUTSIDER_PANEL_SIZE - num_outsiders
        if num_same_needed > len(same_domain_records):
            continue
        for run_idx in range(OUTSIDER_RUNS_PER_SETTING):
            selected_same = random.sample(same_domain_records, num_same_needed) if num_same_needed else []
            selected_outsiders = random.sample(outsider_records, num_outsiders) if num_outsiders else []
            selected_records = selected_same + selected_outsiders
            random.shuffle(selected_records)

            review_blocks = [
                {
                    "heading": f"{rec['reviewer']} ({rec['domain_source']})",
                    "body": rec["text"],
                }
                for rec in selected_records
            ]

            response = run_editor_simulation(review_blocks, include_paper_text=True, paper_text=PAPER_TEXT)

            OUTSIDER_EDITOR_EXPERIMENT_RESULTS.append(
                {
                    "num_outsiders": num_outsiders,
                    "num_same": num_same_needed,
                    "run_idx": run_idx,
                    "selected_reviewers": [rec["reviewer"] for rec in selected_records],
                    "editor_response": response,
                    "parsed_decision": parse_editor_decision(response),
                    "parsed_confidence": parse_editor_confidence(response),
                    "parsed_score": parse_editor_score(response),
                }
            )
            pbar.update(1)

outsider_results_df = pd.DataFrame(OUTSIDER_EDITOR_EXPERIMENT_RESULTS)
display(OUTSIDER_EXPERIMENT_CONFIG)
display(outsider_results_df.head())

if not outsider_results_df.empty:
    decision_summary, confidence_summary, score_summary = summarize_decisions(
        outsider_results_df,
        group_key="num_outsiders",
    )
    if not decision_summary.empty:
        decision_summary = decision_summary.reindex(index=outsider_counts, fill_value=0)
        print("Editor decision counts by number of outsider reviewers:")
        display(decision_summary)

    if confidence_summary is not None and not confidence_summary.empty:
        confidence_summary = confidence_summary.reindex(index=outsider_counts)
        confidence_summary = confidence_summary.fillna({"count": 0})
        sem = confidence_summary["std"] / np.sqrt(confidence_summary["count"].replace(0, np.nan))
        confidence_summary["sem"] = sem.fillna(0)
        print("Editor confidence by number of outsider reviewers:")
        display(confidence_summary)

        fig, ax = plt.subplots(figsize=(8, 4))
        ax.errorbar(
            confidence_summary.index,
            confidence_summary["mean"],
            yerr=confidence_summary["sem"],
            fmt="-o",
            capsize=4,
            color="#1f77b4",
        )
        ax.set_xlabel("Number of outsider reviewers")
        ax.set_ylabel("Editor confidence (0-1)")
        ax.set_title("Editor confidence vs. outsider reviewer mix")
        ax.set_ylim(0, 1)
        ax.grid(alpha=0.3)
        plt.tight_layout()
        plt.show()
    else:
        print("Editor confidences could not be parsed for these simulations.")
    if score_summary is not None and not score_summary.empty:
        score_summary = score_summary.reindex(index=outsider_counts)
        score_summary = score_summary.fillna({"count": 0})
        score_summary["sem"] = score_summary["std"] / np.sqrt(score_summary["count"].replace(0, np.nan))
        score_summary["sem"] = score_summary["sem"].fillna(0)
        print("Editor quality score by number of outsider reviewers:")
        display(score_summary)
        fig, ax = plt.subplots(figsize=(8, 4))
        ax.errorbar(
            score_summary.index,
            score_summary["mean"],
            yerr=score_summary["sem"],
            fmt="-o",
            capsize=4,
            color="#d62728",
        )
        ax.set_xlabel("Number of outsider reviewers")
        ax.set_ylabel("Editor quality score (1-10)")
        ax.set_title("Editor quality score vs. outsider reviewer mix")
        ax.set_ylim(1, 10)
        ax.grid(alpha=0.3)
        plt.tight_layout()
        plt.show()
    else:
        print("Editor scores could not be parsed for these simulations.")
else:
    print("No simulations were recorded; verify AI reviews exist and rerun this cell.")
# Out:
# Outsider reviewer simulations: 100%|██████████| 18/18 [01:36<00:00,  5.35s/it]
# {'panel_size': 5, 'runs_per_setting': 3, 'outsider_counts': [0, 1, 2, 3, 4, 5]}
#    num_outsiders  num_same  run_idx  \
# 0              0         5        0
# 1              0         5        1
# 2              0         5        2
# 3              1         4        0
# 4              1         4        1
#
#                                   selected_reviewers  \
# 0  [AI Reviewer_2: Junior faculty in Causality, A...
# 1  [AI Reviewer_1: Junior faculty in Causality, A...
# 2  [AI Reviewer_1: Junior faculty in Causality, A...
# 3  [AI Reviewer_5: Junior faculty in Causality, A...
# 4  [AI Reviewer_2: Junior faculty in Causality, A...
#
#                                      editor_response  parsed_decision  \
# 0  {\n  "decision": "Accept (Poster)",\n  "confid...  Accept (Poster)
# 1  {\n  "decision": "Accept (Poster)",\n  "confid...  Accept (Poster)
# 2  {\n  "decision": "Accept (Poster)",\n  "confid...  Accept (Poster)
# 3  {\n  "decision": "Accept (Poster)",\n  "confid...  Accept (Poster)
# 4  {\n  "decision": "Accept (Poster)",\n  "confid...  Accept (Poster)
#
#    parsed_confidence  parsed_score
# 0               0.85           8.0
# 1               0.80           8.0
# 2               0.85           8.0
# 3               0.80           8.0
# 4               0.80           8.0
# Editor decision counts by number of outsider reviewers:
# parsed_decision  Accept (Poster)
# num_outsiders
# 0                              3
# 1                              3
# 2                              3
# 3                              3
# 4                              3
# 5                              3
# Editor confidence by number of outsider reviewers:
#                    mean       std  count       sem
# num_outsiders
# 0              0.833333  0.028868      3  0.016667
# 1              0.800000  0.000000      3  0.000000
# 2              0.833333  0.028868      3  0.016667
# 3              0.850000  0.000000      3  0.000000
# 4              0.850000  0.000000      3  0.000000
# 5              0.816667  0.028868      3  0.016667
# Editor quality score by number of outsider reviewers:
#                mean  std  count  sem
# num_outsiders
# 0               8.0  0.0      3  0.0
# 1               8.0  0.0      3  0.0
# 2               8.0  0.0      3  0.0
# 3               8.0  0.0      3  0.0
# 4               8.0  0.0      3  0.0
# 5               8.0  0.0      3  0.0

# %%
outsider_results_df
# Out:
#     num_outsiders  num_same  run_idx  \
# 0               0         5        0
# 1               0         5        1
# 2               0         5        2
# 3               1         4        0
# 4               1         4        1
# 5               1         4        2
# 6               2         3        0
# 7               2         3        1
# 8               2         3        2
# 9               3         2        0
# 10              3         2        1
# 11              3         2        2
# 12              4         1        0
# 13              4         1        1
# 14              4         1        2
# 15              5         0        0
# 16              5         0        1
# 17              5         0        2
#
#                                    selected_reviewers  \
# 0   [AI Reviewer_5: Junior faculty in Causality, A...
# 1   [AI Reviewer_2: Junior faculty in Causality, A...
# 2   [AI Reviewer_5: Junior faculty in Causality, A...
# 3   [AI Reviewer_3: Junior faculty in Causality, A...
# 4   [AI Reviewer_3: Junior faculty in Causality, A...
# 5   [AI Reviewer_4: Junior faculty in Causality, A...
# 6   [AI Reviewer_5: Junior faculty in Causality, A...
# 7   [AI Reviewer_2: Junior faculty in Causality, A...
# 8   [AI Reviewer_5: Junior faculty in Causality, A...
# 9   [AI Reviewer_5: Junior faculty in Causality, A...
# 10  [AI Reviewer_1: Junior faculty in Causality, A...
# 11  [AI Reviewer_7: Junior faculty in Machine Lear...
# 12  [AI Reviewer_9: Junior faculty in Machine Lear...
# 13  [AI Reviewer_9: Junior faculty in Machine Lear...
# 14  [AI Reviewer_7: Junior faculty in Machine Lear...
# 15  [AI Reviewer_10: Junior faculty in Machine Lea...
# 16  [AI Reviewer_9: Junior faculty in Machine Lear...
# 17  [AI Reviewer_8: Junior faculty in Machine Lear...
#
#                                       editor_response  parsed_decision  \
# 0   {\n  "decision": "Accept (Poster)",\n  "confid...  Accept (Poster)
# 1   {\n  "decision": "Accept (Poster)",\n  "confid...  Accept (Poster)
# 2   {\n  "decision": "Accept (Poster)",\n  "confid...  Accept (Poster)
# 3   {\n  "decision": "Accept (Poster)",\n  "confid...  Accept (Poster)
# 4   {\n  "decision": "Accept (Poster)",\n  "confid...  Accept (Poster)
# 5   {\n  "decision": "Accept (Poster)",\n  "confid...  Accept (Poster)
# 6   {\n  "decision": "Accept (Poster)",\n  "confid...  Accept (Poster)
# 7   {\n  "decision": "Accept (Poster)",\n  "confid...  Accept (Poster)
# 8   {\n  "decision": "Accept (Poster)",\n  "confid...  Accept (Poster)
# 9   {\n  "decision": "Accept (Poster)",\n  "confid...  Accept (Poster)
# 10  {\n  "decision": "Accept (Poster)",\n  "confid...  Accept (Poster)
# 11  {\n  "decision": "Accept (Poster)",\n  "confid...  Accept (Poster)
# 12  {\n  "decision": "Accept (Poster)",\n  "confid...  Accept (Poster)
# 13  {\n  "decision": "Accept (Poster)",\n  "confid...  Accept (Poster)
# 14  {\n  "decision": "Accept (Poster)",\n  "confid...  Accept (Poster)
# 15  {\n  "decision": "Accept (Oral)",\n  "confiden...    Accept (Oral)
# 16  {\n  "decision": "Accept (Poster)",\n  "confid...  Accept (Poster)
# 17  {\n  "decision": "Accept (Poster)",\n  "confid...  Accept (Poster)
#
#     parsed_confidence  parsed_score
# 0                0.85           8.0
# 1                0.85           8.0
# 2                0.90           8.0
# 3                0.85           8.0
# 4                0.85           8.0
# 5                0.85           8.0
# 6                0.85           8.0
# 7                0.80           8.0
# 8                0.85           8.0
# 9                0.85           8.0
# 10               0.85           8.0
# 11               0.85           8.0
# 12               0.85           8.0
# 13               0.85           8.0
# 14               0.85           8.0
# 15               0.85           9.0
# 16               0.85           8.0
# 17               0.80           8.0

# %% [markdown]
# # Summarization Data Pack
# Use the next cell to print a compact JSON summary of your run. After it finishes:
#
# 1. Right-click the cell output and choose **Copy Cell Output**.
# 2. Paste the JSON into the shared Google Sheet so we can combine everyone’s results.
#
# Make sure you’ve generated AI reviews and run the simulation cells before executing the exporter.

# %%
# Export a JSON-friendly summary for classroom aggregation
def _to_serializable(value):
    """Best-effort conversion of numpy/pandas types into JSON-safe values."""
    if isinstance(value, (np.integer, np.int64, np.int32)):
        return int(value)
    if isinstance(value, (np.floating, np.float64, np.float32)):
        return float(value)
    if isinstance(value, np.bool_):
        return bool(value)
    if isinstance(value, (list, tuple, set)):
        return [_to_serializable(v) for v in value]
    if isinstance(value, dict):
        return {k: _to_serializable(v) for k, v in value.items()}
    if isinstance(value, pd.DataFrame):
        return [_to_serializable(row) for row in value.to_dict(orient="records")]
    if isinstance(value, pd.Series):
        return _to_serializable(value.to_dict())
    return value

def _safe_df_records(df: Optional[pd.DataFrame]) -> List[Dict[str, Any]]:
    if df is None or df.empty:
        return []
    return [
        {k: _to_serializable(v) for k, v in row.items()}
        for row in df.to_dict(orient="records")
    ]

def build_classroom_datapack(indent: int = 2) -> Dict[str, Any]:
    """Collect review aspects + editor outcomes into a sharable JSON blob."""
    pack: Dict[str, Any] = {
        "generated_at": datetime.utcnow().isoformat() + "Z",
        "paper": {
            "paper_id": locals().get("PAPER_ID", "unknown"),
            "paper_domain": locals().get("PAPER_DOMAIN", "unknown"),
        },
        "ai_panel_state": AI_PANEL_STATE,
    }

    if 'ASPECT_SCORES_DF' in globals() and not ASPECT_SCORES_DF.empty:
        aspect_df = ASPECT_SCORES_DF.copy()
        pack["aspect_scores"] = {
            "mean_by_source": _to_serializable(
                aspect_df.groupby("source")[ASPECT_COLUMNS].mean().round(4).to_dict(orient="index")
            ),
            "std_by_source": _to_serializable(
                aspect_df.groupby("source")[ASPECT_COLUMNS].std(ddof=0).round(4).to_dict(orient="index")
            ),
            "mean_by_domain": _to_serializable(
                aspect_df.groupby("domain")[ASPECT_COLUMNS].mean().round(4).to_dict(orient="index")
            ),
            "std_by_domain": _to_serializable(
                aspect_df.groupby("domain")[ASPECT_COLUMNS].std(ddof=0).round(4).to_dict(orient="index")
            ),
            "counts_by_source": _to_serializable(
                aspect_df.groupby("source").size().to_dict()
            ),
            "counts_by_domain": _to_serializable(
                aspect_df.groupby("domain").size().to_dict()
            ),
        }

    if 'AI_REVIEWS' in globals() and AI_REVIEWS:
        pack["ai_review_personas"] = [review.get("reviewer") for review in AI_REVIEWS]

    if 'AI_EDITOR_AI_REVIEWERS_SIMULATION_RESULTS' in globals() and AI_EDITOR_AI_REVIEWERS_SIMULATION_RESULTS:
        mixture_df = pd.DataFrame(AI_EDITOR_AI_REVIEWERS_SIMULATION_RESULTS)
        if "parsed_confidence" not in mixture_df.columns:
            mixture_df["parsed_confidence"] = mixture_df["editor_response"].map(parse_editor_confidence)
        if "parsed_score" not in mixture_df.columns:
            mixture_df["parsed_score"] = mixture_df["editor_response"].map(parse_editor_score)
        decision_counts, confidence_summary, score_summary = summarize_decisions(
            mixture_df,
            group_key="num_ai_reviews",
        )
        human_ai_entry = {
            "config": {
                "num_ai_reviews_tested": NUM_AI_REVIEWS_TO_TEST,
                "num_shuffle_runs": NUM_SHUFFLE_RUNS,
            },
            "runs": _safe_df_records(
                mixture_df[
                    [
                        "num_ai_reviews",
                        "run_idx",
                        "replacement_indices",
                        "review_sources",
                        "parsed_decision",
                        "parsed_confidence",
                        "parsed_score",
                    ]
                ]
            ),
        }
        if not decision_counts.empty:
            human_ai_entry["decision_counts"] = _to_serializable(decision_counts.to_dict(orient="index"))
        if confidence_summary is not None and not confidence_summary.empty:
            human_ai_entry["confidence_summary"] = _safe_df_records(confidence_summary.reset_index())
        if score_summary is not None and not score_summary.empty:
            human_ai_entry["score_summary"] = _safe_df_records(score_summary.reset_index())
        pack["human_ai_mixture"] = human_ai_entry

    if 'OUTSIDER_EDITOR_EXPERIMENT_RESULTS' in globals() and OUTSIDER_EDITOR_EXPERIMENT_RESULTS:
        outsider_df = pd.DataFrame(OUTSIDER_EDITOR_EXPERIMENT_RESULTS)
        decision_counts, confidence_summary, score_summary = summarize_decisions(
            outsider_df,
            group_key="num_outsiders",
        )
        outsider_entry = {
            "config": OUTSIDER_EXPERIMENT_CONFIG,
            "runs": _safe_df_records(
                outsider_df[
                    [
                        "num_outsiders",
                        "num_same",
                        "run_idx",
                        "parsed_decision",
                        "parsed_confidence",
                        "parsed_score",
                    ]
                ]
            ),
        }
        if not decision_counts.empty:
            outsider_entry["decision_counts"] = _to_serializable(decision_counts.to_dict(orient="index"))
        if confidence_summary is not None and not confidence_summary.empty:
            outsider_entry["confidence_summary"] = _safe_df_records(confidence_summary.reset_index())
        if score_summary is not None and not score_summary.empty:
            outsider_entry["score_summary"] = _safe_df_records(score_summary.reset_index())
        pack["outsider_mixture"] = outsider_entry

    json_payload = json.dumps(_to_serializable(pack), indent=indent, ensure_ascii=False)
    return json_payload

classroom_pack = build_classroom_datapack()

# %%
# report this to the google form: https://forms.gle/95yCMJhwqn73LKzM7
print(classroom_pack)
# Out:
# {
#   "generated_at": "2025-12-02T01:43:56.016649Z",
#   "paper": {
#     "paper_id": "unknown",
#     "paper_domain": "unknown"
#   },
#   "ai_panel_state": [
#     {
#       "domain": "same",
#       "seniority": "Junior faculty"
#     },
#     {
#       "domain": "same",
#       "seniority": "Junior faculty"
#     },
#     {
#       "domain": "same",
#       "seniority": "Junior faculty"
#     },
#     {
#       "domain": "same",
#       "seniority": "Junior faculty"
#     },
#     {
#       "domain": "same",
#       "seniority": "Junior faculty"
#     },
#     {
#       "domain": "Machine Learning",
#       "seniority": "Junior faculty"
#     },
#     {
#       "domain": "Machine Learning",
#       "seniority": "Junior faculty"
#     },
#     {
#       "domain": "Machine Learning",
#       "seniority": "Junior faculty"
#     },
#     {
#       "domain": "Machine Learning",
#       "seniority": "Junior faculty"
#     },
#     {
#       "domain": "Machine Learning",
#       "seniority": "Junior faculty"
#     }
#   ],
#   "aspect_scores": {
#     "mean_by_source": {
#       "AI": {
#         "accuracy": 3.8,
#         "clarity": 3.8,
#         "consistency": 2.8,
#         "novelty": 4.4,
#         "replicability": 3.0,
#         "thoroughness": 3.4,
#         "positive": 4.0,
#         "negative": 2.6
#       },
#       "human": {
#         "accuracy": 3.6,
#         "clarity": 3.0,
#         "consistency": 2.8,
#         "novelty": 3.8,
#         "replicability": 2.0,
#         "thoroughness": 3.2,
#         "positive": 3.8,
#         "negative": 3.4
#       }
#     },
#     "std_by_source": {
#       "AI": {
#         "accuracy": 0.4,
#         "clarity": 0.4,
#         "consistency": 0.4,
#         "novelty": 0.4899,
#         "replicability": 0.6325,
#         "thoroughness": 0.4899,
#         "positive": 0.0,
#         "negative": 0.4899
#       },
#       "human": {
#         "accuracy": 0.4899,
#         "clarity": 0.0,
#         "consistency": 0.4,
#         "novelty": 0.9798,
#         "replicability": 0.6325,
#         "thoroughness": 0.7483,
#         "positive": 0.4,
#         "negative": 0.4899
#       }
#     },
#     "mean_by_domain": {
#       "Causality": {
#         "accuracy": 3.7778,
#         "clarity": 3.3333,
#         "consistency": 2.8889,
#         "novelty": 4.1111,
#         "replicability": 2.5556,
#         "thoroughness": 3.3333,
#         "positive": 3.8889,
#         "negative": 3.0
#       },
#       "Video Understanding": {
#         "accuracy": 3.0,
#         "clarity": 4.0,
#         "consistency": 2.0,
#         "novelty": 4.0,
#         "replicability": 2.0,
#         "thoroughness": 3.0,
#         "positive": 4.0,
#         "negative": 3.0
#       }
#     },
#     "std_by_domain": {
#       "Causality": {
#         "accuracy": 0.4157,
#         "clarity": 0.4714,
#         "consistency": 0.3143,
#         "novelty": 0.8749,
#         "replicability": 0.8315,
#         "thoroughness": 0.6667,
#         "positive": 0.3143,
#         "negative": 0.6667
#       },
#       "Video Understanding": {
#         "accuracy": 0.0,
#         "clarity": 0.0,
#         "consistency": 0.0,
#         "novelty": 0.0,
#         "replicability": 0.0,
#         "thoroughness": 0.0,
#         "positive": 0.0,
#         "negative": 0.0
#       }
#     },
#     "counts_by_source": {
#       "AI": 5,
#       "human": 5
#     },
#     "counts_by_domain": {
#       "Causality": 9,
#       "Video Understanding": 1
#     }
#   },
#   "ai_review_personas": [
#     "AI Reviewer_1: Junior faculty in Causality",
#     "AI Reviewer_2: Junior faculty in Causality",
#     "AI Reviewer_3: Junior faculty in Causality",
#     "AI Reviewer_4: Junior faculty in Causality",
#     "AI Reviewer_5: Junior faculty in Causality",
#     "AI Reviewer_6: Junior faculty in Machine Learning",
#     "AI Reviewer_7: Junior faculty in Machine Learning",
#     "AI Reviewer_8: Junior faculty in Machine Learning",
#     "AI Reviewer_9: Junior faculty in Machine Learning",
#     "AI Reviewer_10: Junior faculty in Machine Learning"
#   ],
#   "human_ai_mixture": {
#     "config": {
#       "num_ai_reviews_tested": [
#         2
#       ],
#       "num_shuffle_runs": 3
#     },
#     "runs": [
#       {
#         "num_ai_reviews": 1,
#         "run_idx": 0,
#         "replacement_indices": [
#           3
#         ],
#         "review_sources": [
#           "human",
#           "human",
#           "human",
#           "AI",
#           "human"
#         ],
#         "parsed_decision": "Reject",
#         "parsed_confidence": 0.75,
#         "parsed_score": 5.0
#       },
#       {
#         "num_ai_reviews": 1,
#         "run_idx": 1,
#         "replacement_indices": [
#           0
#         ],
#         "review_sources": [
#           "AI",
#           "human",
#           "human",
#           "human",
#           "human"
#         ],
#         "parsed_decision": "Accept (Poster)",
#         "parsed_confidence": 0.75,
#         "parsed_score": 7.0
#       },
#       {
#         "num_ai_reviews": 1,
#         "run_idx": 2,
#         "replacement_indices": [
#           4
#         ],
#         "review_sources": [
#           "human",
#           "human",
#           "human",
#           "human",
#           "AI"
#         ],
#         "parsed_decision": "Reject",
#         "parsed_confidence": 0.8,
#         "parsed_score": 6.0
#       },
#       {
#         "num_ai_reviews": 2,
#         "run_idx": 0,
#         "replacement_indices": [
#           0,
#           4
#         ],
#         "review_sources": [
#           "AI",
#           "human",
#           "human",
#           "human",
#           "AI"
#         ],
#         "parsed_decision": "Accept (Poster)",
#         "parsed_confidence": 0.8,
#         "parsed_score": 7.0
#       },
#       {
#         "num_ai_reviews": 2,
#         "run_idx": 1,
#         "replacement_indices": [
#           0,
#           3
#         ],
#         "review_sources": [
#           "AI",
#           "human",
#           "human",
#           "AI",
#           "human"
#         ],
#         "parsed_decision": "Accept (Poster)",
#         "parsed_confidence": 0.85,
#         "parsed_score": 8.0
#       },
#       {
#         "num_ai_reviews": 2,
#         "run_idx": 2,
#         "replacement_indices": [
#           1,
#           3
#         ],
#         "review_sources": [
#           "human",
#           "AI",
#           "human",
#           "AI",
#           "human"
#         ],
#         "parsed_decision": "Accept (Poster)",
#         "parsed_confidence": 0.8,
#         "parsed_score": 7.0
#       },
#       {
#         "num_ai_reviews": 3,
#         "run_idx": 0,
#         "replacement_indices": [
#           0,
#           3,
#           4
#         ],
#         "review_sources": [
#           "AI",
#           "human",
#           "human",
#           "AI",
#           "AI"
#         ],
#         "parsed_decision": "Accept (Poster)",
#         "parsed_confidence": 0.85,
#         "parsed_score": 8.0
#       },
#       {
#         "num_ai_reviews": 3,
#         "run_idx": 1,
#         "replacement_indices": [
#           2,
#           3,
#           4
#         ],
#         "review_sources": [
#           "human",
#           "human",
#           "AI",
#           "AI",
#           "AI"
#         ],
#         "parsed_decision": "Accept (Poster)",
#         "parsed_confidence": 0.75,
#         "parsed_score": 7.0
#       },
#       {
#         "num_ai_reviews": 3,
#         "run_idx": 2,
#         "replacement_indices": [
#           0,
#           1,
#           3
#         ],
#         "review_sources": [
#           "AI",
#           "AI",
#           "human",
#           "AI",
#           "human"
#         ],
#         "parsed_decision": "Accept (Spotlight)",
#         "parsed_confidence": 0.85,
#         "parsed_score": 9.0
#       }
#     ],
#     "decision_counts": {
#       "1": {
#         "Accept (Poster)": 1,
#         "Accept (Spotlight)": 0,
#         "Reject": 2
#       },
#       "2": {
#         "Accept (Poster)": 3,
#         "Accept (Spotlight)": 0,
#         "Reject": 0
#       },
#       "3": {
#         "Accept (Poster)": 2,
#         "Accept (Spotlight)": 1,
#         "Reject": 0
#       }
#     },
#     "confidence_summary": [
#       {
#         "num_ai_reviews": 1,
#         "mean": 0.7666666666666666,
#         "std": 0.028867513459481298,
#         "count": 3
#       },
#       {
#         "num_ai_reviews": 2,
#         "mean": 0.8166666666666668,
#         "std": 0.028867513459481256,
#         "count": 3
#       },
#       {
#         "num_ai_reviews": 3,
#         "mean": 0.8166666666666668,
#         "std": 0.05773502691896258,
#         "count": 3
#       }
#     ],
#     "score_summary": [
#       {
#         "num_ai_reviews": 1,
#         "mean": 6.0,
#         "std": 1.0,
#         "count": 3
#       },
#       {
#         "num_ai_reviews": 2,
#         "mean": 7.333333333333333,
#         "std": 0.5773502691896257,
#         "count": 3
#       },
#       {
#         "num_ai_reviews": 3,
#         "mean": 8.0,
#         "std": 1.0,
#         "count": 3
#       }
#     ]
#   },
#   "outsider_mixture": {
#     "config": {
#       "panel_size": 5,
#       "runs_per_setting": 3,
#       "outsider_counts": [
#         0,
#         1,
#         2,
#         3,
#         4,
#         5
#       ]
#     },
#     "runs": [
#       {
#         "num_outsiders": 0,
#         "num_same": 5,
#         "run_idx": 0,
#         "parsed_decision": "Accept (Poster)",
#         "parsed_confidence": 0.85,
#         "parsed_score": 8.0
#       },
#       {
#         "num_outsiders": 0,
#         "num_same": 5,
#         "run_idx": 1,
#         "parsed_decision": "Accept (Poster)",
#         "parsed_confidence": 0.8,
#         "parsed_score": 8.0
#       },
#       {
#         "num_outsiders": 0,
#         "num_same": 5,
#         "run_idx": 2,
#         "parsed_decision": "Accept (Poster)",
#         "parsed_confidence": 0.85,
#         "parsed_score": 8.0
#       },
#       {
#         "num_outsiders": 1,
#         "num_same": 4,
#         "run_idx": 0,
#         "parsed_decision": "Accept (Poster)",
#         "parsed_confidence": 0.8,
#         "parsed_score": 8.0
#       },
#       {
#         "num_outsiders": 1,
#         "num_same": 4,
#         "run_idx": 1,
#         "parsed_decision": "Accept (Poster)",
#         "parsed_confidence": 0.8,
#         "parsed_score": 8.0
#       },
#       {
#         "num_outsiders": 1,
#         "num_same": 4,
#         "run_idx": 2,
#         "parsed_decision": "Accept (Poster)",
#         "parsed_confidence": 0.8,
#         "parsed_score": 8.0
#       },
#       {
#         "num_outsiders": 2,
#         "num_same": 3,
#         "run_idx": 0,
#         "parsed_decision": "Accept (Poster)",
#         "parsed_confidence": 0.85,
#         "parsed_score": 8.0
#       },
#       {
#         "num_outsiders": 2,
#         "num_same": 3,
#         "run_idx": 1,
#         "parsed_decision": "Accept (Poster)",
#         "parsed_confidence": 0.8,
#         "parsed_score": 8.0
#       },
#       {
#         "num_outsiders": 2,
#         "num_same": 3,
#         "run_idx": 2,
#         "parsed_decision": "Accept (Poster)",
#         "parsed_confidence": 0.85,
#         "parsed_score": 8.0
#       },
#       {
#         "num_outsiders": 3,
#         "num_same": 2,
#         "run_idx": 0,
#         "parsed_decision": "Accept (Poster)",
#         "parsed_confidence": 0.85,
#         "parsed_score": 8.0
#       },
#       {
#         "num_outsiders": 3,
#         "num_same": 2,
#         "run_idx": 1,
#         "parsed_decision": "Accept (Poster)",
#         "parsed_confidence": 0.85,
#         "parsed_score": 8.0
#       },
#       {
#         "num_outsiders": 3,
#         "num_same": 2,
#         "run_idx": 2,
#         "parsed_decision": "Accept (Poster)",
#         "parsed_confidence": 0.85,
#         "parsed_score": 8.0
#       },
#       {
#         "num_outsiders": 4,
#         "num_same": 1,
#         "run_idx": 0,
#         "parsed_decision": "Accept (Poster)",
#         "parsed_confidence": 0.85,
#         "parsed_score": 8.0
#       },
#       {
#         "num_outsiders": 4,
#         "num_same": 1,
#         "run_idx": 1,
#         "parsed_decision": "Accept (Poster)",
#         "parsed_confidence": 0.85,
#         "parsed_score": 8.0
#       },
#       {
#         "num_outsiders": 4,
#         "num_same": 1,
#         "run_idx": 2,
#         "parsed_decision": "Accept (Poster)",
#         "parsed_confidence": 0.85,
#         "parsed_score": 8.0
#       },
#       {
#         "num_outsiders": 5,
#         "num_same": 0,
#         "run_idx": 0,
#         "parsed_decision": "Accept (Poster)",
#         "parsed_confidence": 0.8,
#         "parsed_score": 8.0
#       },
#       {
#         "num_outsiders": 5,
#         "num_same": 0,
#         "run_idx": 1,
#         "parsed_decision": "Accept (Poster)",
#         "parsed_confidence": 0.8,
#         "parsed_score": 8.0
#       },
#       {
#         "num_outsiders": 5,
#         "num_same": 0,
#         "run_idx": 2,
#         "parsed_decision": "Accept (Poster)",
#         "parsed_confidence": 0.85,
#         "parsed_score": 8.0
#       }
#     ],
#     "decision_counts": {
#       "0": {
#         "Accept (Poster)": 3
#       },
#       "1": {
#         "Accept (Poster)": 3
#       },
#       "2": {
#         "Accept (Poster)": 3
#       },
#       "3": {
#         "Accept (Poster)": 3
#       },
#       "4": {
#         "Accept (Poster)": 3
#       },
#       "5": {
#         "Accept (Poster)": 3
#       }
#     },
#     "confidence_summary": [
#       {
#         "num_outsiders": 0,
#         "mean": 0.8333333333333334,
#         "std": 0.02886751345948125,
#         "count": 3
#       },
#       {
#         "num_outsiders": 1,
#         "mean": 0.8000000000000002,
#         "std": 0.0,
#         "count": 3
#       },
#       {
#         "num_outsiders": 2,
#         "mean": 0.8333333333333334,
#         "std": 0.02886751345948125,
#         "count": 3
#       },
#       {
#         "num_outsiders": 3,
#         "mean": 0.85,
#         "std": 0.0,
#         "count": 3
#       },
#       {
#         "num_outsiders": 4,
#         "mean": 0.85,
#         "std": 0.0,
#         "count": 3
#       },
#       {
#         "num_outsiders": 5,
#         "mean": 0.8166666666666668,
#         "std": 0.028867513459481266,
#         "count": 3
#       }
#     ],
#     "score_summary": [
#       {
#         "num_outsiders": 0,
#         "mean": 8.0,
#         "std": 0.0,
#         "count": 3
#       },
#       {
#         "num_outsiders": 1,
#         "mean": 8.0,
#         "std": 0.0,
#         "count": 3
#       },
#       {
#         "num_outsiders": 2,
#         "mean": 8.0,
#         "std": 0.0,
#         "count": 3
#       },
#       {
#         "num_outsiders": 3,
#         "mean": 8.0,
#         "std": 0.0,
#         "count": 3
#       },
#       {
#         "num_outsiders": 4,
#         "mean": 8.0,
#         "std": 0.0,
#         "count": 3
#       },
#       {
#         "num_outsiders": 5,
#         "mean": 8.0,
#         "std": 0.0,
#         "count": 3
#       }
#     ]
#   }
# }
